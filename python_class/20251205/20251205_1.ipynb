# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sqlalchemy import create_engine 
import oracledb

# %%
# !pip install oracledb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 20.9 MB/s  0:00:00
# ...

# %%
oracle_connection_str = (
    f"oracle+oracledb://KDTUSER:oracle_4U"
    "@193.123.247.105:1521/"
    "srvinv.sub01081722130.dbcsvcn.oraclevcn.com"
)
db_engine = create_engine(oracle_connection_str)

# %%
df = pd.read_sql("select * from caregiver", con=oracle_connection_str)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File src/oracledb/impl/thin/connection.pyx:404, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
#
# File src/oracledb/impl/thin/protocol.pyx:288, in oracledb.thin_impl.Protocol._connect_phase_one()
#
# File src/oracledb/impl/thin/protocol.pyx:470, in oracledb.thin_impl.Protocol._process_message()
#
# File src/oracledb/impl/thin/protocol.pyx:446, in oracledb.thin_impl.Protocol._process_message()
#
# File src/oracledb/impl/thin/messages/connect.pyx:99, in oracledb.thin_impl.ConnectMessage.process()
#
# File ~/miniconda3/lib/python3.9/site-packages/oracledb/errors.py:199, in _raise_err(error_num, context_error_message, cause, **args)
#     198 error = _create_err(error_num, context_error_message, cause, **args)
# --> 199 raise error.exc_type(error) from cause
#
# ...

# %%
# !pip install pandas numpy matplotlib seaborn SQLAlchemy oracledb

# %%
import oracledb
import os
# Thick mode 초기화 (연결 전에 먼저 호출)
oracledb.init_oracle_client(lib_dir=r"C:\instantclient-basic-windows.x64-21.19.0.0.0dbru\instantclient_21_19")

username = 'KDTUSER'        # 또는 생성한 'myuser'
password = 'oracle_4U'          # 설정한 비밀번호
dsn = '193.123.247.105:1521/srvinv.sub01081722130.dbcsvcn.oraclevcn.com' # 중요: 서비스명이 XE가 아니라 FREE 입니다.

try:
    connection = oracledb.connect(user=username, password=password, dsn=dsn) 
    cursor = connection.cursor() 
    # DB 버전 확인 쿼리
    sql = "SELECT banner_full FROM v$version"
    cursor.execute(sql)
    
    # 4. 결과 가져오기
    result = cursor.fetchone()
    print("성공적으로 연결되었습니다!")
    print(f"Server Version: {result[0]}")

except oracledb.Error as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 4
#       2 import os
#       3 # Thick mode 초기화 (연결 전에 먼저 호출)
# ----> 4 oracledb.init_oracle_client(lib_dir=r"C:\instantclient-basic-windows.x64-21.19.0.0.0dbru\instantclient_21_19")
#       6 username = 'KDTUSER'        # 또는 생성한 'myuser'
#       7 password = 'oracle_4U'          # 설정한 비밀번호
#
# File ~/miniconda3/lib/python3.9/site-packages/oracledb/utils.py:182, in init_oracle_client(lib_dir, config_dir, error_url, driver_name)
#      90 def init_oracle_client(
#      91     lib_dir: Optional[Union[str, bytes]] = None,
#      92     config_dir: Optional[Union[str, bytes]] = None,
#      93     error_url: Optional[str] = None,
#      94     driver_name: Optional[str] = None,
#      95 ):
#      96     """
#      97     Enables python-oracledb Thick mode by initializing the Oracle Client
# ...

# %%
# 1. 필수 패키지 설치
sudo apt update
sudo apt install libaio1t64 wget unzip -y

# 2. Oracle Instant Client 다운로드
cd /tmp
wget https://download.oracle.com/otn_software/linux/instantclient/2340000/instantclient-basic-linux.x64-23.4.0.24.05.zip

# 3. 압축 해제 및 설치
sudo mkdir -p /opt/oracle
sudo unzip instantclient-basic-linux.x64-23.4.0.24.05.zip -d /opt/oracle

# 4. 심볼릭 링크 생성
cd /opt/oracle/instantclient_23_4
sudo ln -s libclntsh.so.23.1 libclntsh.so

# 5. 시스템 라이브러리 경로 설정
sudo sh -c "echo /opt/oracle/instantclient_23_4 > /etc/ld.so.conf.d/oracle-instantclient.conf"
sudo ldconfig

# 6. 환경 변수 설정
echo 'export LD_LIBRARY_PATH=/opt/oracle/instantclient_23_4:$LD_LIBRARY_PATH' >> ~/.bashrc
source ~/.bashrc
