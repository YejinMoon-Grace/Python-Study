# %% [markdown]
# # 함수
# ## 함수 만들기
# ### 기본적인 함수

# %%
def print_3_times():
    print("안녕하세요")
    print("안녕하세요")
    print("안녕하세요")

print_3_times()
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ### 매개변수의 기본

# %%
def print_n_times(value, n):
    for i in range(n):
        print(value)

print_n_times("안녕하세요", 5)
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ### 가변 매개변수 함수

# %%
def print_n_times(n, *values):
    # n번 반복합니다.
    for i in range(n):
        # values는 리스트처럼 활용합니다.
        for value in values:
            print(value)
        # 단순한 줄바꿈
        print()

# 함수를 호출합니다.
print_n_times(3, "안녕하세요", "즐거운", "파이썬 프로그래밍")
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %% [markdown]
# ### 기본 매개변수

# %%
def print_n_times(value, n = 2):
    # n번 반복합니다.
    for i in range(n):
        print(value)

# 함수를 호출합니다.
print_n_times("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ### 키워드 매개변수

# %%
def print_n_times(*values, n=2):
    # n번 반복합니다.
    for i in range(n):
        # values는 리스트처럼 활용합니다.
        for value in values:
            print(value)
        # 단순한 줄바꿈
        print()

# 함수를 호출합니다.
print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍", n = 3)
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %% [markdown]
# ### 여러 함수 호출 형태

# %%
def test(a, b = 10, c = 100):
    print(a + b + c)

# 1) 기본 형태
test(10, 20, 30)
# 2) 키워드 매개변수로 모든 매개변수를 지정한 형태
test(a=10, b=100, c=200)
# 3) 키워드 매개변수로 모든 매개변수를 마구잡이로 지정한 형태
test(c=10, a=100, b=200)
# 4) 키워드 매개변수로 일부 매개변수만 지정한 형태
test(10, c=200)
# Out:
# 60
# 310
# 310
# 220

# %% [markdown]
# ### 자료 없이 리턴하기

# %%
# 함수를 정의합니다.
def return_test():
    print("A 위치입니다.")
    return
    print("B 위치입니다.")

# 함수를 호출합니다.
return_test()
# Out:
# A 위치입니다.

# %% [markdown]
# ### 자료와 함께 리턴하기

# %%
# 함수를 정의합니다.
def return_test():
    return 100

# 함수를 호출합니다.
value = return_test()
print(value)
# Out:
# 100

# %% [markdown]
# ### 아무것도 리턴하지 않았을 때의 리턴값

# %%
# 함수를 정의합니다.
def return_test():
    return

# 함수를 호출합니다.
value = return_test()
print(value)
# Out:
# None

# %% [markdown]
# ### 범위 내부의 정수를 모두 더하는 함수

# %%
# 함수를 선언합니다.
def sum_all(start, end):
    # 변수를 선언합니다.
    output = 0
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(start, end + 1):
        output += i
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("0 to 100:", sum_all(0, 100))
print("0 to 1000:", sum_all(0, 1000))
print("50 to 100:", sum_all(50, 100))
print("500 to 100:", sum_all(500, 1000))
# Out:
# 0 to 100: 5050
# 0 to 1000: 500500
# 50 to 100: 3825
# 500 to 100: 375750

# %% [markdown]
# ### 기본 매개변수와 키워드 매개변수를 활용해 범위의 정수를 더하는 함수

# %%
# 함수를 선언합니다.
def sum_all(start=0, end=100, step=1):
    # 변수를 선언합니다.
    output = 0
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(start, end + 1, step):
        output += i
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("A.", sum_all(0, 100, 10))
print("B.", sum_all(end=100))
print("C.", sum_all(end=100, step=2))
# Out:
# A. 550
# B. 5050
# C. 2550

# %% [markdown]
# - 호출
#     - 함수를 실행하는 행위
# - 매개변수
#     - 함수의 괄호 내부에 넣는 것을 의미
# - 리턴값
#     - 함수의 최종적인 결과를 의미
# - 가변 매개변수 함수
#     - 매개변수를 원하는 만큼 받을 수 있는 함수
# - 기본 매개변수
#     - 매개변수에 아무것도 넣지 않아도 들어가는 값

# %% [markdown]
# ### 확인문제
# 1. 다음과 같이 방정식을 파이썬 함수로 만들어 보세요.
#     예: f(x) = x
#     def f(x):
#         return x
#     print(f(10))
#
#     1. f(x) = 2x + 1
#         def f(x):
#             return 2 * x + 1
#     print(f(10))
#
#     2. f(x) = x^2 + 2x + 1
#         def f(x):
#             return (x * x) + (2 * x) + 1
#     print(f(10))

# %%
# 1. f(x) = 2x + 1
def f(x):
    return 2 * x + 1
print(f(10))
# Out:
# 21

# %%
# 2. f(x) = x^2 + 2x + 1
def f(x):
    return (x * x) + (2 * x) + 1
print(f(10))
# Out:
# 121

# %% [markdown]
# 2. 다음 빈칸을 채워 매개변수로 전달된 값들을 모두 곱해서 리턴하는 가변 매개변수 함수를 만들어 보세요.

# %%
def mul(*values):
    output = 1
    for value in values:
        output *= value
    return output

# 함수를 호출합니다.
print(mul(5, 7, 9, 10))
# Out:
# 3150

# %% [markdown]
# 3. 다음 중 오류가 발생하는 코드를 고르세요.
#     1. def function(*values, valueA, valueB):
#             pass
#        function(1, 2, 3, 4, 5)
#     2. def function(*values, valueA=10, valueB=20):
#             pass
#        function(1, 2, 3, 4, 5)
#     3. def function(valueA, valueB, *values):
#             pass
#        function(1, 2, 3, 4, 5)
#     4. def function(valueA=10, valueB=20, *values):
#             pass
#        function(1, 2, 3, 4, 5)
#     > 정답: 1

# %% [markdown]
# ## 함수의 활용
# ### 반복문으로 팩토리얼 구하기

# %%
# 함수를 선언합니다.
def factorial(n):
    # 변수를 선언합니다.
    output = 1
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(1, n + 1):
        output += 1
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("1!:", factorial(1))
print("1!:", factorial(2))
print("1!:", factorial(3))
print("1!:", factorial(4))
print("1!:", factorial(5))
# Out:
# 1!: 2
# 1!: 3
# 1!: 4
# 1!: 5
# 1!: 6

# %% [markdown]
# ### 재귀 함수를 사용해 팩토리얼 구하기

# %%
# 함수를 선언합니다.
def factorial(n):
    # n이 0이라면 1을 리턴
    if n == 0:
        return 1
    # n이 0이 아니라면 n * (n - 1)!을 리턴
    else:
        return n * factorial(n - 1)

# 함수를 호출합니다.
print("1!:", factorial(1))
print("1!:", factorial(2))
print("1!:", factorial(3))
print("1!:", factorial(4))
print("1!:", factorial(5))
# Out:
# 1!: 1
# 1!: 2
# 1!: 6
# 1!: 24
# 1!: 120

# %% [markdown]
# ### 재귀 함수로 구현한 피보나치 수열 (1)

# %%
# 함수를 선언합니다.
def fibonacci(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# 함수를 호출합니다.
print("fibonacci(1):", fibonacci(1))
print("fibonacci(1):", fibonacci(2))
print("fibonacci(1):", fibonacci(3))
print("fibonacci(1):", fibonacci(4))
print("fibonacci(1):", fibonacci(5))
# Out:
# fibonacci(1): 1
# fibonacci(1): 1
# fibonacci(1): 2
# fibonacci(1): 3
# fibonacci(1): 5

# %% [markdown]
# ### 재귀 함수로 구현한 피보나치 수열 (2)

# %%
# 변수를 선언합니다.
counter = 0

# 함수를 선언합니다.
def fibonacci(n):
    # 어떤 피보나치 수를 구하는지 출력합니다.
    print("fibonacci({})를 구합니다.".format(n))
    global counter
    counter += 1

    # 피보나치 수를 구합니다.
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
#함수를 호출합니다.
fibonacci(10)
print("---")
print(f"fibonacci(10) 계산에 활용된 덧셈 횟수는 {counter}번입니다.")
# Out:
# fibonacci(10)를 구합니다.
# fibonacci(9)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# ---
# fibonacci(10) 계산에 활용된 덧셈 횟수는 109번입니다.

# %%
### 재귀 함수로 구현한 피보나치 수열(3)

# %%
# 변수를 선언합니다.
counter = 0

# 함수를 선언합니다.
def fibonacci(n):
    counter += 1
    # 피보나치 수를 구합니다.
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# 함수를 호출합니다.
print(fibonacci(10))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[21], line 16
#      13         return fibonacci(n - 1) + fibonacci(n - 2)
#      15 # 함수를 호출합니다.
# ---> 16 print(fibonacci(10))
#
# Cell In[21], line 6, in fibonacci(n)
#       5 def fibonacci(n):
# ----> 6     counter += 1
#       7     # 피보나치 수를 구합니다.
#       8     if n == 1:
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %% [markdown]
# ### 메모화

# %%
# 메모 변수를 만듭니다
dictionary = {
    1: 1,
    2: 1
}

# 함수를 선언합니다.
def fibonacci(n):
    if n in dictionary:
        # 메모가 되어 있으면 메모된 값을 리턴
        return dictionary[n]
    else:
        # 메모가 되어 있지 않으면 값을 구함
        output = fibonacci(n - 1) + fibonacci(n - 2)
        dictionary[n] = output
        return output

# 함수를 호출합니다.
print("fibonacci(10):", fibonacci(10))
print("fibonacci(20):", fibonacci(20))
print("fibonacci(30):", fibonacci(30))
print("fibonacci(40):", fibonacci(40))
print("fibonacci(50):", fibonacci(50))
# Out:
# fibonacci(10): 55
# fibonacci(20): 6765
# fibonacci(30): 832040
# fibonacci(40): 102334155
# fibonacci(50): 12586269025

# %% [markdown]
# ### 리스트 평탄화하기 (1)

# %%
def flatten(data):
    output = []
    for item in data:
        if type(item) == list:
            output += item
        else:
            output.append(item)
    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본: ", example)
print("변환: ", flatten(example))
# Out:
# 원본:  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환:  [1, 2, 3, 4, [5, 6], 7, 8, 9]

# %% [markdown]
# ### 리스트 평탄화하기 (2)

# %%
def flatten(data):
    output = []
    for item in data:
        if type(item) == list:
            output += flatten(item)
        else:
            output.append(item)
    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본: ", example)
print("변환: ", flatten(example ))
# Out:
# 원본:  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환:  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# - 재귀 함수
#     - 내부에서 자기 자신을 호출하는 함수
# - 메모화
#     - 한 번 계산한 값을 저장해 놓은 후 이후에 다시 계산하지 않고 저장된 값을 활용하는 테크닉
# - 조기 리턴
#     - 함수의 흐름 중간에 return 키워드를 사용해서 코드 들여쓰기를 줄이는 등의 효과를 가져오는 테크닉
#
# ### 확인 문제
# 1. 패밀리 레스토랑에서 여러 개의 테이블에 나누어 앉으려고 합니다. 이때 한 사람만 앉는 테이블이 없게 그룹을 지어야 합니다. 인원 수를 나누는 패턴만 구하면 되며, 누가 어디에 앉는지 등은 고려하지 않아도 괜찮습니다. 예를 들어 6명이라면 다음과 같은 네 가지 경우를 생각할 수 있습니다.
#
#     > 2명 + 2명 + 2명       2명 + 4명       3명 + 3명       6명
#
#     한개의 테이블에 앉을 수 있는 최대 사람의 수는 10명입니다. 100명의 사람이 하나 이상의 테이블에 나누어 앉는 패턴의 경우의 수를 구하세요. 소스 코드에서 한글 변수명은 여러분들의 이해를 돕기 위한 것이니, 식별자 작성 규칙에 따라 이름을 정해 주세요.

# %%
min_person = 2
max_person = 10
whole_person = 100
table_seat = {}

def sit_table(remain_person, sit_person):
    key = str ([remain_person, sit_person])

    # 종료
    if key in table_seat:
        return table_seat[key]
    if remain_person < 0:
        return 0
    if remain_person == 0:
        return 1
    
    # 재귀
    count = 0
    for i in range (sit_person, max_person + 1):
        count += sit_table(remain_person - i, i)
    
    # 정리
    table_seat[key] = count

    # 종료
    return count

print(sit_table(whole_person, min_person))
# Out:
# 437420

# %% [markdown]
# ## 함수 고급
# ### 리스트와 튜플의 특이한 사용

# %%
# 리스트와 튜플의 특이한 사용
[a, b] = [10, 20] 
(c, d) = (10, 20) 

# 출력합니다. 
print("a:", a) 
print("b:", b) 
print("c:", c) 
print("d:", d)
# Out:
# a: 10
# b: 20
# c: 10
# d: 20

# %% [markdown]
# ### 괄호가 없는 튜플

# %%
# 괄호가 없는 튜플
tuple_test = 10, 20, 30, 40
print("# 괄호가 없는 튜플의 값과 자료형 출력") 
print("tuple_test:", tuple_test) 
print("type(tuple_test):", type(tuple_test)) 
print() 

# 괄호가 없는 튜플 활용
a, b, c = 10, 20, 30 
print("# 괄호가 없는 튜플을 활용한 할당") 
print("a:", a) 
print("b:", b) 
print("c:", c)
# Out:
# # 괄호가 없는 튜플의 값과 자료형 출력
# tuple_test: (10, 20, 30, 40)
# type(tuple_test): <class 'tuple'>
#
# # 괄호가 없는 튜플을 활용한 할당
# a: 10
# b: 20
# c: 30

# %% [markdown]
# ### 변수의 값을 교환하는 튜플

# %%
a, b = 10, 20 
print("# 교환 전 값") 
print("a:", a) 
print("b:", b) 
print() 

# 값을 교환합니다. 

a, b = b, a 
print("# 교환 후 값") 
print("a:", a) 
print("b:", b) 
print()
# Out:
# # 교환 전 값
# a: 10
# b: 20
#
# # 교환 후 값
# a: 20
# b: 10

# %% [markdown]
# ### 여러 개의 값 리턴하기

# %%
# 함수를 선언합니다. 
def test(): 
    return (10, 20) 

# 여러 개의 값을 리턴받습니다.
a, b = test() 

# 출력합니다. 
print("a:", a)
print("b:", b)
# Out:
# a: 10
# b: 20

# %% [markdown]
# ### 함수의 매개변수로 함수 전달하기

# %%
# 매개변수로 받은 함수를
def call_10_times(func): 
    for i in range(10):
        func() 
        
# 간단한 출력하는 함수
def print_hello(): 
    print(" 안녕하세요")
    
# 조합하기
call_10_times(print_hello)
# Out:
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요
#  안녕하세요

# %% [markdown]
# ### map() 함수와 filter() 함수

# %%
# 함수를 선언합니다. 
def power(item):
    return item * item 
def under_3(item): 
    return item < 3 

# 변수를 선언합니다. 
list_input_a = [1, 2, 3, 4, 5] 
# map () 함수를 사용합니다. 
output_a = map(power, list_input_a) 
print("# map() 함수의 실행 결과") 
print("map(power, list_input_a):", output_a)
print("map(power, list_input_a):", list(output_a))
print() 

# filter() 함수를 사용합니다. 
output_b = filter(under_3, list_input_a)
print("filter() 함수의 실행 결과")
print("filter(under_3, list_input_a):", output_b) 
print("filter(under_3, list_input_a):", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x7aee8869c580>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x7aee8869c520>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# ### 람다

# %%
# 함수를 선언합니다. 
power = lambda x: x * x 
under_3 = lambda x: x < 3 

# 변수를 선언합니다.
list_input_a = [1, 2, 3, 4, 5] 

# map() 함수를 사용합니다. 
output_a = map(power, list_input_a) 
print("# map() 함수의 실행 결과")
print("map(power, list_input_a):", output_a) 
print("map(power, list_input_a):", list(output_a)) 
print() 

# filter() 함수를 사용합니다. 
output_b = filter(under_3, list_input_a) 
print("# filter() 함수의 실행 결과") 
print("filter(under_3, list_input_a):", output_b)
print("filter(under_3, list_input_a):", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x7aee884a0070>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x7aee8869eac0>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# ### 인라인 람다

# %%
# 변수를 선언합니다. 
list_input_a = [1, 2, 3, 4, 5] 

# map() 함수를 사용합니다. 
output_a = map(lambda x: x * x, list_input_a)
print("# map() 함수의 실행 결과") 
print("map(power, list_input_a):", output_a) 
print("map(power, list_input_a):", list(output_a)) 
print() 

# filter() 함수를 사용합니다. 
output_b = filter(lambda x: x < 3, list_input_a)
print("# filter() 함수의 실행 결과") 
print("filter(under_3, list_input_a):", output_b) 
print("filter(under_3, list_input_a):", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x7aee886763d0>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x7aee88676fd0>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# ### 파일 열고 닫기

# %%
# 파일을 엽니다. 
file = open("basic.txt", "w") 

# 파일에 텍스트를 쏩니다. 
file.write("Hello Python Programming...!")

# 파일을 닫습니다.
file.close()

# %% [markdown]
# ### read() 함수로 텍스트 읽기

# %%
# 파일을 엽니다.
with open("basic.txt", "r") as file: 
    # 파일을 읽고 출력합니다. 
    contents = file.read() 
print(contents)
# Out:
# Hello Python Programming...!

# %% [markdown]
# ### 랜덤하게 1000명의 키와 몸무게 만들기

# %%
# 랜덤한 숫자를 만들기 위해 가져옵니다.
import random

# 간단한 한글 리스트를 만듭니다. 
hanguls = list ("가나다라마바사아자차카타파하") 

# 파일을 쓰기 모드로 엽니다. 
with open("info.txt", "w") as file: 
    for i in range(1000): 
        # 랜덤한 값으로 변수를 생성합니다. 
        name = random.choice(hanguls) + random.choice(hanguls) 
        weight = random.randrange(40, 100) 
        height = random.randrange(140, 200) 
        
        # 텍스트를 쏩니다. 
        file.write("{}, {}, {}\n".format(name, weight, height))

# %% [markdown]
# ### 반복문으로 파일 한 줄씩 읽기

# %%
with open("info.txt", "r") as file: 
    for line in file:
        # 변수를 선언합니다. 
        (name, weight, height) = line.strip().split(", ") 
        
        # 데이터가 문제없는지 확인합니다: 문제가 있으면 지나감
        if (not name) or (not weight) or (not height):
            continue 
        
        # 결과를 계산합니다. 
        bmi = int(weight) / ((int(height) / 100) ** 2) 
        result = "" 
        if 25 <= bmi: 
            result = "과체중" 
        elif 18.5 <= bmi: 
            result = "정상 체중" 
        else: result = "저체중" 
        
        # 출력합니다.
        print('\n'.join([ 
            "이름: {}", 
            "몸무게: {}", 
            "키: {}", 
            "BMI: {}", 
            "결과: {}"
        ]).format(name, weight, height, bmi, result)) 
        print()
# Out:
# 이름: 차카
# 몸무게: 96
# 키: 151
# BMI: 42.103416516819436
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 67
# 키: 170
# BMI: 23.18339100346021
# 결과: 정상 체중
#
# 이름: 마카
# 몸무게: 95
# 키: 149
# BMI: 42.790865276338906
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 88
# 키: 188
# BMI: 24.898143956541425
# 결과: 정상 체중
#
# 이름: 가파
# 몸무게: 58
# 키: 140
# BMI: 29.59183673469388
# 결과: 과체중
#
# 이름: 자다
# 몸무게: 62
# 키: 176
# BMI: 20.015495867768596
# 결과: 정상 체중
#
# 이름: 다다
# 몸무게: 83
# 키: 175
# BMI: 27.102040816326532
# 결과: 과체중
#
# 이름: 사하
# 몸무게: 89
# 키: 168
# BMI: 31.533446712018144
# 결과: 과체중
#
# 이름: 하바
# 몸무게: 47
# 키: 163
# BMI: 17.68978885166924
# 결과: 저체중
#
# 이름: 카타
# 몸무게: 41
# 키: 177
# BMI: 13.086916275655144
# 결과: 저체중
#
# 이름: 마아
# 몸무게: 42
# 키: 155
# BMI: 17.48178980228928
# 결과: 저체중
#
# 이름: 마바
# 몸무게: 56
# 키: 178
# BMI: 17.67453604342886
# 결과: 저체중
#
# 이름: 라다
# 몸무게: 57
# 키: 152
# BMI: 24.67105263157895
# 결과: 정상 체중
#
# 이름: 카사
# 몸무게: 55
# 키: 179
# BMI: 17.165506694547613
# 결과: 저체중
#
# 이름: 마바
# 몸무게: 66
# 키: 143
# BMI: 32.27541689080151
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 57
# 키: 182
# BMI: 17.208066658616108
# 결과: 저체중
#
# 이름: 자다
# 몸무게: 88
# 키: 195
# BMI: 23.14266929651545
# 결과: 정상 체중
#
# 이름: 사파
# 몸무게: 50
# 키: 178
# BMI: 15.780835753061481
# 결과: 저체중
#
# 이름: 하사
# 몸무게: 65
# 키: 175
# BMI: 21.224489795918366
# 결과: 정상 체중
#
# 이름: 하하
# 몸무게: 54
# 키: 161
# BMI: 20.832529609197174
# 결과: 정상 체중
#
# 이름: 바라
# 몸무게: 91
# 키: 144
# BMI: 43.88503086419753
# 결과: 과체중
#
# 이름: 파사
# 몸무게: 55
# 키: 159
# BMI: 21.75546853368142
# 결과: 정상 체중
#
# 이름: 다마
# 몸무게: 52
# 키: 177
# BMI: 16.59804015448945
# 결과: 저체중
#
# 이름: 마다
# 몸무게: 57
# 키: 159
# BMI: 22.54657648036074
# 결과: 정상 체중
#
# 이름: 나카
# 몸무게: 60
# 키: 141
# BMI: 30.179568432171422
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 88
# 키: 145
# BMI: 41.85493460166468
# 결과: 과체중
#
# 이름: 사하
# 몸무게: 77
# 키: 154
# BMI: 32.46753246753247
# 결과: 과체중
#
# 이름: 마하
# 몸무게: 41
# 키: 187
# BMI: 11.724670422374102
# 결과: 저체중
#
# 이름: 사아
# 몸무게: 73
# 키: 146
# BMI: 34.24657534246576
# 결과: 과체중
#
# 이름: 마라
# 몸무게: 57
# 키: 196
# BMI: 14.83756768013328
# 결과: 저체중
#
# 이름: 파사
# 몸무게: 88
# 키: 158
# BMI: 35.250761095978206
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 66
# 키: 160
# BMI: 25.781249999999996
# 결과: 과체중
#
# 이름: 파파
# 몸무게: 42
# 키: 160
# BMI: 16.406249999999996
# 결과: 저체중
#
# 이름: 카라
# 몸무게: 99
# 키: 150
# BMI: 44.0
# 결과: 과체중
#
# 이름: 차마
# 몸무게: 87
# 키: 150
# BMI: 38.666666666666664
# 결과: 과체중
#
# 이름: 카라
# 몸무게: 59
# 키: 157
# BMI: 23.93606231490121
# 결과: 정상 체중
#
# 이름: 가가
# 몸무게: 50
# 키: 158
# BMI: 20.028841531805796
# 결과: 정상 체중
#
# 이름: 자다
# 몸무게: 79
# 키: 159
# BMI: 31.24876389383331
# 결과: 과체중
#
# 이름: 하하
# 몸무게: 73
# 키: 164
# BMI: 27.141582391433676
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 63
# 키: 152
# BMI: 27.268005540166204
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 89
# 키: 149
# BMI: 40.0882843115175
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 96
# 키: 192
# BMI: 26.041666666666668
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 46
# 키: 192
# BMI: 12.47829861111111
# 결과: 저체중
#
# 이름: 가라
# 몸무게: 96
# 키: 156
# BMI: 39.44773175542406
# 결과: 과체중
#
# 이름: 라하
# 몸무게: 92
# 키: 175
# BMI: 30.040816326530614
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 61
# 키: 142
# BMI: 30.251934140051578
# 결과: 과체중
#
# 이름: 사하
# 몸무게: 47
# 키: 182
# BMI: 14.189107595701001
# 결과: 저체중
#
# 이름: 바사
# 몸무게: 53
# 키: 161
# BMI: 20.446742023841672
# 결과: 정상 체중
#
# 이름: 사아
# 몸무게: 49
# 키: 170
# BMI: 16.955017301038065
# 결과: 저체중
#
# 이름: 아아
# 몸무게: 60
# 키: 179
# BMI: 18.726007303142847
# 결과: 정상 체중
#
# 이름: 다차
# 몸무게: 91
# 키: 188
# BMI: 25.746944318696244
# 결과: 과체중
#
# 이름: 다바
# 몸무게: 54
# 키: 163
# BMI: 20.32443825510934
# 결과: 정상 체중
#
# 이름: 자마
# 몸무게: 62
# 키: 159
# BMI: 24.524346347059055
# 결과: 정상 체중
#
# 이름: 파타
# 몸무게: 87
# 키: 175
# BMI: 28.408163265306122
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 78
# 키: 180
# BMI: 24.074074074074073
# 결과: 정상 체중
#
# 이름: 아타
# 몸무게: 78
# 키: 163
# BMI: 29.357521924046825
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 69
# 키: 180
# BMI: 21.296296296296294
# 결과: 정상 체중
#
# 이름: 사다
# 몸무게: 62
# 키: 161
# BMI: 23.9188302920412
# 결과: 정상 체중
#
# 이름: 가타
# 몸무게: 49
# 키: 190
# BMI: 13.573407202216067
# 결과: 저체중
#
# 이름: 마파
# 몸무게: 89
# 키: 163
# BMI: 33.49768527230984
# 결과: 과체중
#
# 이름: 다타
# 몸무게: 47
# 키: 184
# BMI: 13.882325141776937
# 결과: 저체중
#
# 이름: 차사
# 몸무게: 56
# 키: 176
# BMI: 18.078512396694215
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 87
# 키: 198
# BMI: 22.19161310070401
# 결과: 정상 체중
#
# 이름: 사가
# 몸무게: 88
# 키: 192
# BMI: 23.87152777777778
# 결과: 정상 체중
#
# 이름: 차다
# 몸무게: 58
# 키: 186
# BMI: 16.76494392415308
# 결과: 저체중
#
# 이름: 가나
# 몸무게: 58
# 키: 155
# BMI: 24.141519250780433
# 결과: 정상 체중
#
# 이름: 사바
# 몸무게: 57
# 키: 155
# BMI: 23.725286160249738
# 결과: 정상 체중
#
# 이름: 차바
# 몸무게: 65
# 키: 171
# BMI: 22.229061933586404
# 결과: 정상 체중
#
# 이름: 다라
# 몸무게: 42
# 키: 186
# BMI: 12.140131807145334
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 43
# 키: 192
# BMI: 11.664496527777779
# 결과: 저체중
#
# 이름: 나파
# 몸무게: 48
# 키: 198
# BMI: 12.243648607284971
# 결과: 저체중
#
# 이름: 라하
# 몸무게: 84
# 키: 176
# BMI: 27.117768595041323
# 결과: 과체중
#
# 이름: 다사
# 몸무게: 64
# 키: 156
# BMI: 26.298487836949374
# 결과: 과체중
#
# 이름: 나타
# 몸무게: 64
# 키: 196
# BMI: 16.65972511453561
# 결과: 저체중
#
# 이름: 차가
# 몸무게: 71
# 키: 193
# BMI: 19.060914386963407
# 결과: 정상 체중
#
# 이름: 바나
# 몸무게: 99
# 키: 174
# BMI: 32.69916765755053
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 78
# 키: 190
# BMI: 21.606648199445985
# 결과: 정상 체중
#
# 이름: 자사
# 몸무게: 76
# 키: 171
# BMI: 25.990903183885642
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 77
# 키: 154
# BMI: 32.46753246753247
# 결과: 과체중
#
# 이름: 자나
# 몸무게: 65
# 키: 186
# BMI: 18.78829922534397
# 결과: 정상 체중
#
# 이름: 가차
# 몸무게: 96
# 키: 193
# BMI: 25.77250395983785
# 결과: 과체중
#
# 이름: 아나
# 몸무게: 68
# 키: 197
# BMI: 17.52170888196037
# 결과: 저체중
#
# 이름: 사타
# 몸무게: 53
# 키: 140
# BMI: 27.040816326530617
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 93
# 키: 143
# BMI: 45.47899652794759
# 결과: 과체중
#
# 이름: 하사
# 몸무게: 97
# 키: 188
# BMI: 27.44454504300589
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 42
# 키: 158
# BMI: 16.82422688671687
# 결과: 저체중
#
# 이름: 자파
# 몸무게: 84
# 키: 156
# BMI: 34.51676528599605
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 98
# 키: 181
# BMI: 29.913616800463966
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 81
# 키: 143
# BMI: 39.61073891143822
# 결과: 과체중
#
# 이름: 차라
# 몸무게: 48
# 키: 184
# BMI: 14.177693761814744
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 49
# 키: 199
# BMI: 12.373424913512284
# 결과: 저체중
#
# 이름: 마다
# 몸무게: 92
# 키: 184
# BMI: 27.173913043478258
# 결과: 과체중
#
# 이름: 카자
# 몸무게: 60
# 키: 146
# BMI: 28.147870144492405
# 결과: 과체중
#
# 이름: 차차
# 몸무게: 71
# 키: 188
# BMI: 20.088275237664103
# 결과: 정상 체중
#
# 이름: 사자
# 몸무게: 87
# 키: 147
# BMI: 40.261002360127726
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 66
# 키: 156
# BMI: 27.12031558185404
# 결과: 과체중
#
# 이름: 나차
# 몸무게: 59
# 키: 141
# BMI: 29.676575624968567
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 76
# 키: 179
# BMI: 23.719609250647608
# 결과: 정상 체중
#
# 이름: 라하
# 몸무게: 69
# 키: 196
# BMI: 17.961266139108705
# 결과: 저체중
#
# 이름: 자바
# 몸무게: 83
# 키: 156
# BMI: 34.10585141354372
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 48
# 키: 145
# BMI: 22.829964328180736
# 결과: 정상 체중
#
# 이름: 카아
# 몸무게: 66
# 키: 197
# BMI: 17.006364503079183
# 결과: 저체중
#
# 이름: 다마
# 몸무게: 95
# 키: 143
# BMI: 46.457039464032476
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 40
# 키: 193
# BMI: 10.738543316599104
# 결과: 저체중
#
# 이름: 자타
# 몸무게: 65
# 키: 168
# BMI: 23.030045351473927
# 결과: 정상 체중
#
# 이름: 바바
# 몸무게: 96
# 키: 156
# BMI: 39.44773175542406
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 53
# 키: 162
# BMI: 20.195092211553114
# 결과: 정상 체중
#
# 이름: 카카
# 몸무게: 99
# 키: 164
# BMI: 36.808447352766215
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 64
# 키: 153
# BMI: 27.339911999658252
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 40
# 키: 188
# BMI: 11.317338162064283
# 결과: 저체중
#
# 이름: 하타
# 몸무게: 74
# 키: 159
# BMI: 29.270994027135
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 43
# 키: 176
# BMI: 13.881714876033058
# 결과: 저체중
#
# 이름: 차하
# 몸무게: 56
# 키: 157
# BMI: 22.7189744005842
# 결과: 정상 체중
#
# 이름: 자나
# 몸무게: 57
# 키: 199
# BMI: 14.393575919800005
# 결과: 저체중
#
# 이름: 라타
# 몸무게: 49
# 키: 172
# BMI: 16.563007030827475
# 결과: 저체중
#
# 이름: 다파
# 몸무게: 93
# 키: 164
# BMI: 34.577632361689474
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 95
# 키: 159
# BMI: 37.5776274672679
# 결과: 과체중
#
# 이름: 자파
# 몸무게: 86
# 키: 183
# BMI: 25.680074054167036
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 64
# 키: 175
# BMI: 20.897959183673468
# 결과: 정상 체중
#
# 이름: 다타
# 몸무게: 76
# 키: 189
# BMI: 21.27600011197895
# 결과: 정상 체중
#
# 이름: 차바
# 몸무게: 59
# 키: 166
# BMI: 21.410944984758313
# 결과: 정상 체중
#
# 이름: 차다
# 몸무게: 92
# 키: 180
# BMI: 28.39506172839506
# 결과: 과체중
#
# 이름: 파차
# 몸무게: 88
# 키: 154
# BMI: 37.10575139146568
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 58
# 키: 162
# BMI: 22.10028959000152
# 결과: 정상 체중
#
# 이름: 하타
# 몸무게: 61
# 키: 199
# BMI: 15.403651422943865
# 결과: 저체중
#
# 이름: 가차
# 몸무게: 49
# 키: 172
# BMI: 16.563007030827475
# 결과: 저체중
#
# 이름: 가가
# 몸무게: 87
# 키: 162
# BMI: 33.15043438500228
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 56
# 키: 154
# BMI: 23.61275088547816
# 결과: 정상 체중
#
# 이름: 카타
# 몸무게: 51
# 키: 179
# BMI: 15.917106207671422
# 결과: 저체중
#
# 이름: 타자
# 몸무게: 73
# 키: 154
# BMI: 30.78090740428403
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 94
# 키: 142
# BMI: 46.61773457647292
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 98
# 키: 160
# BMI: 38.28124999999999
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 99
# 키: 147
# BMI: 45.81424406497293
# 결과: 과체중
#
# 이름: 마차
# 몸무게: 40
# 키: 168
# BMI: 14.172335600907031
# 결과: 저체중
#
# 이름: 다가
# 몸무게: 60
# 키: 174
# BMI: 19.817677368212443
# 결과: 정상 체중
#
# 이름: 타자
# 몸무게: 47
# 키: 152
# BMI: 20.342797783933516
# 결과: 정상 체중
#
# 이름: 파바
# 몸무게: 80
# 키: 181
# BMI: 24.41927902078691
# 결과: 정상 체중
#
# 이름: 자바
# 몸무게: 63
# 키: 157
# BMI: 25.558846200657225
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 79
# 키: 149
# BMI: 35.58398270348182
# 결과: 과체중
#
# 이름: 하타
# 몸무게: 68
# 키: 178
# BMI: 21.461936624163616
# 결과: 정상 체중
#
# 이름: 사라
# 몸무게: 63
# 키: 191
# BMI: 17.269263452207998
# 결과: 저체중
#
# 이름: 아바
# 몸무게: 75
# 키: 188
# BMI: 21.22000905387053
# 결과: 정상 체중
#
# 이름: 아라
# 몸무게: 97
# 키: 170
# BMI: 33.564013840830455
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 67
# 키: 155
# BMI: 27.887617065556707
# 결과: 과체중
#
# 이름: 나차
# 몸무게: 85
# 키: 172
# BMI: 28.73174689021093
# 결과: 과체중
#
# 이름: 바타
# 몸무게: 61
# 키: 163
# BMI: 22.95908765854944
# 결과: 정상 체중
#
# 이름: 자자
# 몸무게: 46
# 키: 191
# BMI: 12.609303473040761
# 결과: 저체중
#
# 이름: 타마
# 몸무게: 90
# 키: 161
# BMI: 34.72088268199529
# 결과: 과체중
#
# 이름: 아다
# 몸무게: 77
# 키: 158
# BMI: 30.844415958980928
# 결과: 과체중
#
# 이름: 차카
# 몸무게: 56
# 키: 162
# BMI: 21.338210638622158
# 결과: 정상 체중
#
# 이름: 타바
# 몸무게: 91
# 키: 185
# BMI: 26.588750913075234
# 결과: 과체중
#
# 이름: 라가
# 몸무게: 99
# 키: 170
# BMI: 34.256055363321806
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 99
# 키: 194
# BMI: 26.304601976830696
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 49
# 키: 169
# BMI: 17.15626203564301
# 결과: 저체중
#
# 이름: 라가
# 몸무게: 51
# 키: 197
# BMI: 13.141281661470277
# 결과: 저체중
#
# 이름: 가파
# 몸무게: 81
# 키: 161
# BMI: 31.24879441379576
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 86
# 키: 178
# BMI: 27.143037495265748
# 결과: 과체중
#
# 이름: 타아
# 몸무게: 73
# 키: 186
# BMI: 21.10070528384784
# 결과: 정상 체중
#
# 이름: 마다
# 몸무게: 62
# 키: 177
# BMI: 19.789970953429727
# 결과: 정상 체중
#
# 이름: 타카
# 몸무게: 74
# 키: 164
# BMI: 27.513384889946465
# 결과: 과체중
#
# 이름: 바카
# 몸무게: 40
# 키: 185
# BMI: 11.68736303871439
# 결과: 저체중
#
# 이름: 마아
# 몸무게: 73
# 키: 193
# BMI: 19.597841552793366
# 결과: 정상 체중
#
# 이름: 차다
# 몸무게: 55
# 키: 178
# BMI: 17.35891932836763
# 결과: 저체중
#
# 이름: 사자
# 몸무게: 75
# 키: 149
# BMI: 33.782262060267556
# 결과: 과체중
#
# 이름: 타가
# 몸무게: 47
# 키: 160
# BMI: 18.359374999999996
# 결과: 저체중
#
# 이름: 자다
# 몸무게: 53
# 키: 142
# BMI: 26.284467367585798
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 77
# 키: 181
# BMI: 23.503556057507403
# 결과: 정상 체중
#
# 이름: 아나
# 몸무게: 64
# 키: 169
# BMI: 22.40817898532965
# 결과: 정상 체중
#
# 이름: 파파
# 몸무게: 54
# 키: 166
# BMI: 19.5964581216432
# 결과: 정상 체중
#
# 이름: 다라
# 몸무게: 43
# 키: 199
# BMI: 10.858311658796495
# 결과: 저체중
#
# 이름: 라타
# 몸무게: 94
# 키: 176
# BMI: 30.34607438016529
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 77
# 키: 175
# BMI: 25.142857142857142
# 결과: 과체중
#
# 이름: 가마
# 몸무게: 45
# 키: 161
# BMI: 17.360441340997646
# 결과: 저체중
#
# 이름: 마나
# 몸무게: 60
# 키: 169
# BMI: 21.007667798746546
# 결과: 정상 체중
#
# 이름: 파가
# 몸무게: 53
# 키: 160
# BMI: 20.703124999999996
# 결과: 정상 체중
#
# 이름: 바자
# 몸무게: 92
# 키: 148
# BMI: 42.00146092037984
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 77
# 키: 157
# BMI: 31.238589800803275
# 결과: 과체중
#
# 이름: 가사
# 몸무게: 94
# 키: 184
# BMI: 27.764650283553873
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 44
# 키: 153
# BMI: 18.79618949976505
# 결과: 정상 체중
#
# 이름: 차다
# 몸무게: 45
# 키: 197
# BMI: 11.595248524826715
# 결과: 저체중
#
# 이름: 파자
# 몸무게: 84
# 키: 143
# BMI: 41.07780331556556
# 결과: 과체중
#
# 이름: 아카
# 몸무게: 62
# 키: 178
# BMI: 19.568236333796236
# 결과: 정상 체중
#
# 이름: 사아
# 몸무게: 88
# 키: 196
# BMI: 22.907122032486466
# 결과: 정상 체중
#
# 이름: 라파
# 몸무게: 93
# 키: 178
# BMI: 29.352354500694357
# 결과: 과체중
#
# 이름: 하아
# 몸무게: 72
# 키: 144
# BMI: 34.72222222222222
# 결과: 과체중
#
# 이름: 타사
# 몸무게: 46
# 키: 151
# BMI: 20.174553747642648
# 결과: 정상 체중
#
# 이름: 다바
# 몸무게: 75
# 키: 172
# BMI: 25.351541373715524
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 94
# 키: 156
# BMI: 38.62590401051939
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 72
# 키: 186
# BMI: 20.811654526534856
# 결과: 정상 체중
#
# 이름: 가마
# 몸무게: 88
# 키: 185
# BMI: 25.712198685171657
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 61
# 키: 192
# BMI: 16.54730902777778
# 결과: 저체중
#
# 이름: 라하
# 몸무게: 84
# 키: 186
# BMI: 24.280263614290668
# 결과: 정상 체중
#
# 이름: 하타
# 몸무게: 78
# 키: 165
# BMI: 28.650137741046834
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 83
# 키: 196
# BMI: 21.605581007913372
# 결과: 정상 체중
#
# 이름: 다사
# 몸무게: 86
# 키: 140
# BMI: 43.87755102040817
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 59
# 키: 189
# BMI: 16.516894823773132
# 결과: 저체중
#
# 이름: 가다
# 몸무게: 97
# 키: 147
# BMI: 44.88870378083207
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 81
# 키: 151
# BMI: 35.5247576860664
# 결과: 과체중
#
# 이름: 하라
# 몸무게: 40
# 키: 179
# BMI: 12.484004868761899
# 결과: 저체중
#
# 이름: 다자
# 몸무게: 66
# 키: 180
# BMI: 20.37037037037037
# 결과: 정상 체중
#
# 이름: 다나
# 몸무게: 67
# 키: 148
# BMI: 30.58802045288532
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 84
# 키: 143
# BMI: 41.07780331556556
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 86
# 키: 198
# BMI: 21.93653708805224
# 결과: 정상 체중
#
# 이름: 카사
# 몸무게: 65
# 키: 167
# BMI: 23.306680053067517
# 결과: 정상 체중
#
# 이름: 바바
# 몸무게: 90
# 키: 173
# BMI: 30.071168431955627
# 결과: 과체중
#
# 이름: 자파
# 몸무게: 55
# 키: 168
# BMI: 19.48696145124717
# 결과: 정상 체중
#
# 이름: 나가
# 몸무게: 57
# 키: 143
# BMI: 27.874223678419487
# 결과: 과체중
#
# 이름: 파바
# 몸무게: 84
# 키: 160
# BMI: 32.81249999999999
# 결과: 과체중
#
# 이름: 나가
# 몸무게: 50
# 키: 164
# BMI: 18.590124925639504
# 결과: 정상 체중
#
# 이름: 아하
# 몸무게: 69
# 키: 163
# BMI: 25.970115548195267
# 결과: 과체중
#
# 이름: 아나
# 몸무게: 46
# 키: 161
# BMI: 17.746228926353147
# 결과: 저체중
#
# 이름: 사라
# 몸무게: 96
# 키: 181
# BMI: 29.303134824944294
# 결과: 과체중
#
# 이름: 사차
# 몸무게: 75
# 키: 172
# BMI: 25.351541373715524
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 48
# 키: 156
# BMI: 19.72386587771203
# 결과: 정상 체중
#
# 이름: 라차
# 몸무게: 68
# 키: 166
# BMI: 24.677021338365513
# 결과: 정상 체중
#
# 이름: 사가
# 몸무게: 55
# 키: 152
# BMI: 23.80540166204986
# 결과: 정상 체중
#
# 이름: 자카
# 몸무게: 40
# 키: 193
# BMI: 10.738543316599104
# 결과: 저체중
#
# 이름: 마가
# 몸무게: 84
# 키: 164
# BMI: 31.231409875074366
# 결과: 과체중
#
# 이름: 다자
# 몸무게: 77
# 키: 162
# BMI: 29.340039628105465
# 결과: 과체중
#
# 이름: 타마
# 몸무게: 79
# 키: 162
# BMI: 30.102118579484827
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 78
# 키: 142
# BMI: 38.68280103154136
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 89
# 키: 179
# BMI: 27.776910832995224
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 64
# 키: 176
# BMI: 20.66115702479339
# 결과: 정상 체중
#
# 이름: 카바
# 몸무게: 54
# 키: 153
# BMI: 23.06805074971165
# 결과: 정상 체중
#
# 이름: 아가
# 몸무게: 51
# 키: 187
# BMI: 14.584346135148271
# 결과: 저체중
#
# 이름: 자차
# 몸무게: 43
# 키: 179
# BMI: 13.420305233919041
# 결과: 저체중
#
# 이름: 바바
# 몸무게: 70
# 키: 148
# BMI: 31.95763330898466
# 결과: 과체중
#
# 이름: 파바
# 몸무게: 93
# 키: 162
# BMI: 35.43667123914037
# 결과: 과체중
#
# 이름: 파라
# 몸무게: 79
# 키: 148
# BMI: 36.06647187728269
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 86
# 키: 143
# BMI: 42.05584625165045
# 결과: 과체중
#
# 이름: 마하
# 몸무게: 84
# 키: 176
# BMI: 27.117768595041323
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 76
# 키: 176
# BMI: 24.535123966942148
# 결과: 정상 체중
#
# 이름: 자파
# 몸무게: 55
# 키: 151
# BMI: 24.121749046094468
# 결과: 정상 체중
#
# 이름: 타자
# 몸무게: 90
# 키: 150
# BMI: 40.0
# 결과: 과체중
#
# 이름: 자나
# 몸무게: 86
# 키: 149
# BMI: 38.7369938291068
# 결과: 과체중
#
# 이름: 타사
# 몸무게: 75
# 키: 155
# BMI: 31.217481789802285
# 결과: 과체중
#
# 이름: 라라
# 몸무게: 81
# 키: 177
# BMI: 25.854639471416256
# 결과: 과체중
#
# 이름: 다바
# 몸무게: 96
# 키: 182
# BMI: 28.982007003985025
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 67
# 키: 173
# BMI: 22.386314277122523
# 결과: 정상 체중
#
# 이름: 아아
# 몸무게: 42
# 키: 176
# BMI: 13.558884297520661
# 결과: 저체중
#
# 이름: 타나
# 몸무게: 66
# 키: 178
# BMI: 20.830703194041156
# 결과: 정상 체중
#
# 이름: 차다
# 몸무게: 61
# 키: 147
# BMI: 28.228978666296452
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 77
# 키: 187
# BMI: 22.019502988361115
# 결과: 정상 체중
#
# 이름: 타마
# 몸무게: 89
# 키: 154
# BMI: 37.52740765727779
# 결과: 과체중
#
# 이름: 바다
# 몸무게: 93
# 키: 170
# BMI: 32.17993079584775
# 결과: 과체중
#
# 이름: 라사
# 몸무게: 53
# 키: 145
# BMI: 25.20808561236623
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 80
# 키: 178
# BMI: 25.24933720489837
# 결과: 과체중
#
# 이름: 라다
# 몸무게: 44
# 키: 173
# BMI: 14.701460122289419
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 63
# 키: 189
# BMI: 17.63668430335097
# 결과: 저체중
#
# 이름: 마가
# 몸무게: 89
# 키: 163
# BMI: 33.49768527230984
# 결과: 과체중
#
# 이름: 가마
# 몸무게: 47
# 키: 186
# BMI: 13.585385593710253
# 결과: 저체중
#
# 이름: 카차
# 몸무게: 61
# 키: 149
# BMI: 27.476239809017613
# 결과: 과체중
#
# 이름: 마다
# 몸무게: 95
# 키: 180
# BMI: 29.320987654320987
# 결과: 과체중
#
# 이름: 나파
# 몸무게: 50
# 키: 182
# BMI: 15.094795314575533
# 결과: 저체중
#
# 이름: 나마
# 몸무게: 77
# 키: 150
# BMI: 34.22222222222222
# 결과: 과체중
#
# 이름: 아하
# 몸무게: 81
# 키: 146
# BMI: 37.999624695064746
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 98
# 키: 169
# BMI: 34.31252407128602
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 70
# 키: 148
# BMI: 31.95763330898466
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 71
# 키: 173
# BMI: 23.722810651876106
# 결과: 정상 체중
#
# 이름: 사나
# 몸무게: 91
# 키: 182
# BMI: 27.47252747252747
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 84
# 키: 188
# BMI: 23.766410140334994
# 결과: 정상 체중
#
# 이름: 파파
# 몸무게: 73
# 키: 179
# BMI: 22.783308885490467
# 결과: 정상 체중
#
# 이름: 마라
# 몸무게: 44
# 키: 169
# BMI: 15.405623052414134
# 결과: 저체중
#
# 이름: 아바
# 몸무게: 47
# 키: 190
# BMI: 13.019390581717452
# 결과: 저체중
#
# 이름: 하하
# 몸무게: 92
# 키: 155
# BMI: 38.29344432882414
# 결과: 과체중
#
# 이름: 타라
# 몸무게: 95
# 키: 192
# BMI: 25.770399305555557
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 60
# 키: 167
# BMI: 21.513858510523864
# 결과: 정상 체중
#
# 이름: 카차
# 몸무게: 42
# 키: 187
# BMI: 12.010637993651518
# 결과: 저체중
#
# 이름: 아타
# 몸무게: 87
# 키: 153
# BMI: 37.165192874535435
# 결과: 과체중
#
# 이름: 자다
# 몸무게: 90
# 키: 155
# BMI: 37.460978147762745
# 결과: 과체중
#
# 이름: 마파
# 몸무게: 73
# 키: 141
# BMI: 36.718474925808565
# 결과: 과체중
#
# 이름: 타라
# 몸무게: 90
# 키: 184
# BMI: 26.583175803402646
# 결과: 과체중
#
# 이름: 차타
# 몸무게: 96
# 키: 152
# BMI: 41.551246537396125
# 결과: 과체중
#
# 이름: 다가
# 몸무게: 82
# 키: 196
# BMI: 21.345272802998753
# 결과: 정상 체중
#
# 이름: 다바
# 몸무게: 85
# 키: 192
# BMI: 23.057725694444446
# 결과: 정상 체중
#
# 이름: 마카
# 몸무게: 46
# 키: 177
# BMI: 14.682881675125282
# 결과: 저체중
#
# 이름: 자타
# 몸무게: 94
# 키: 199
# BMI: 23.73677432388071
# 결과: 정상 체중
#
# 이름: 다라
# 몸무게: 63
# 키: 146
# BMI: 29.555263651717024
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 96
# 키: 185
# BMI: 28.04967129291453
# 결과: 과체중
#
# 이름: 라사
# 몸무게: 76
# 키: 149
# BMI: 34.232692221071126
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 57
# 키: 150
# BMI: 25.333333333333332
# 결과: 과체중
#
# 이름: 타아
# 몸무게: 57
# 키: 153
# BMI: 24.34960912469563
# 결과: 정상 체중
#
# 이름: 마라
# 몸무게: 48
# 키: 182
# BMI: 14.491003501992513
# 결과: 저체중
#
# 이름: 아자
# 몸무게: 83
# 키: 183
# BMI: 24.78425751739377
# 결과: 정상 체중
#
# 이름: 카카
# 몸무게: 83
# 키: 171
# BMI: 28.384802161348794
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 44
# 키: 189
# BMI: 12.317684275356234
# 결과: 저체중
#
# 이름: 마하
# 몸무게: 58
# 키: 179
# BMI: 18.101807059704754
# 결과: 저체중
#
# 이름: 자마
# 몸무게: 71
# 키: 142
# BMI: 35.2112676056338
# 결과: 과체중
#
# 이름: 차나
# 몸무게: 71
# 키: 162
# BMI: 27.053802773967377
# 결과: 과체중
#
# 이름: 라자
# 몸무게: 72
# 키: 161
# BMI: 27.776706145596233
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 68
# 키: 172
# BMI: 22.985397512168742
# 결과: 정상 체중
#
# 이름: 가나
# 몸무게: 95
# 키: 169
# BMI: 33.2621406813487
# 결과: 과체중
#
# 이름: 차타
# 몸무게: 85
# 키: 174
# BMI: 28.075042938300964
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 43
# 키: 145
# BMI: 20.451843043995243
# 결과: 정상 체중
#
# 이름: 마차
# 몸무게: 74
# 키: 140
# BMI: 37.75510204081633
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 42
# 키: 174
# BMI: 13.87237415774871
# 결과: 저체중
#
# 이름: 라하
# 몸무게: 54
# 키: 191
# BMI: 14.802225816178286
# 결과: 저체중
#
# 이름: 라나
# 몸무게: 94
# 키: 148
# BMI: 42.9145361577794
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 90
# 키: 180
# BMI: 27.777777777777775
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 82
# 키: 171
# BMI: 28.042816593139772
# 결과: 과체중
#
# 이름: 바아
# 몸무게: 77
# 키: 185
# BMI: 22.498173849525198
# 결과: 정상 체중
#
# 이름: 사자
# 몸무게: 62
# 키: 165
# BMI: 22.77318640955005
# 결과: 정상 체중
#
# 이름: 아라
# 몸무게: 83
# 키: 155
# BMI: 34.54734651404786
# 결과: 과체중
#
# 이름: 파차
# 몸무게: 92
# 키: 165
# BMI: 33.792470156106525
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 49
# 키: 146
# BMI: 22.987427284668797
# 결과: 정상 체중
#
# 이름: 파차
# 몸무게: 78
# 키: 175
# BMI: 25.46938775510204
# 결과: 과체중
#
# 이름: 카바
# 몸무게: 61
# 키: 144
# BMI: 29.41743827160494
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 95
# 키: 187
# BMI: 27.166919271354622
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 67
# 키: 186
# BMI: 19.366400739969936
# 결과: 정상 체중
#
# 이름: 아나
# 몸무게: 95
# 키: 163
# BMI: 35.75595618954421
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 71
# 키: 179
# BMI: 22.15910864205237
# 결과: 정상 체중
#
# 이름: 사파
# 몸무게: 45
# 키: 179
# BMI: 14.044505477357136
# 결과: 저체중
#
# 이름: 라차
# 몸무게: 77
# 키: 165
# BMI: 28.282828282828287
# 결과: 과체중
#
# 이름: 파가
# 몸무게: 83
# 키: 148
# BMI: 37.892622352081816
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 65
# 키: 175
# BMI: 21.224489795918366
# 결과: 정상 체중
#
# 이름: 바바
# 몸무게: 40
# 키: 163
# BMI: 15.05513944822914
# 결과: 저체중
#
# 이름: 하자
# 몸무게: 53
# 키: 198
# BMI: 13.519028670543822
# 결과: 저체중
#
# 이름: 아나
# 몸무게: 45
# 키: 197
# BMI: 11.595248524826715
# 결과: 저체중
#
# 이름: 하사
# 몸무게: 48
# 키: 153
# BMI: 20.504933999743688
# 결과: 정상 체중
#
# 이름: 사가
# 몸무게: 48
# 키: 158
# BMI: 19.227687870533565
# 결과: 정상 체중
#
# 이름: 자차
# 몸무게: 53
# 키: 183
# BMI: 15.826092149661081
# 결과: 저체중
#
# 이름: 다아
# 몸무게: 69
# 키: 145
# BMI: 32.81807372175981
# 결과: 과체중
#
# 이름: 가타
# 몸무게: 47
# 키: 168
# BMI: 16.65249433106576
# 결과: 저체중
#
# 이름: 다다
# 몸무게: 76
# 키: 153
# BMI: 32.46614549959418
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 50
# 키: 195
# BMI: 13.149243918474689
# 결과: 저체중
#
# 이름: 파사
# 몸무게: 95
# 키: 148
# BMI: 43.371073776479186
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 55
# 키: 151
# BMI: 24.121749046094468
# 결과: 정상 체중
#
# 이름: 가카
# 몸무게: 60
# 키: 177
# BMI: 19.15158479364167
# 결과: 정상 체중
#
# 이름: 바라
# 몸무게: 65
# 키: 191
# BMI: 17.81749403799238
# 결과: 저체중
#
# 이름: 아타
# 몸무게: 47
# 키: 148
# BMI: 21.4572680788897
# 결과: 정상 체중
#
# 이름: 가하
# 몸무게: 91
# 키: 193
# BMI: 24.43018604526296
# 결과: 정상 체중
#
# 이름: 아자
# 몸무게: 59
# 키: 156
# BMI: 24.243918474687703
# 결과: 정상 체중
#
# 이름: 하라
# 몸무게: 70
# 키: 189
# BMI: 19.59631589261219
# 결과: 정상 체중
#
# 이름: 다다
# 몸무게: 95
# 키: 160
# BMI: 37.10937499999999
# 결과: 과체중
#
# 이름: 아카
# 몸무게: 58
# 키: 174
# BMI: 19.157088122605362
# 결과: 정상 체중
#
# 이름: 사가
# 몸무게: 98
# 키: 141
# BMI: 49.29329510587999
# 결과: 과체중
#
# 이름: 하나
# 몸무게: 47
# 키: 172
# BMI: 15.886965927528395
# 결과: 저체중
#
# 이름: 자파
# 몸무게: 78
# 키: 143
# BMI: 38.14367450731088
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 64
# 키: 164
# BMI: 23.795359904818564
# 결과: 정상 체중
#
# 이름: 자하
# 몸무게: 71
# 키: 172
# BMI: 23.99945916711736
# 결과: 정상 체중
#
# 이름: 아자
# 몸무게: 98
# 키: 196
# BMI: 25.510204081632654
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 97
# 키: 175
# BMI: 31.6734693877551
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 97
# 키: 161
# BMI: 37.42139577948381
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 53
# 키: 157
# BMI: 21.50188648626719
# 결과: 정상 체중
#
# 이름: 차카
# 몸무게: 41
# 키: 173
# BMI: 13.69908784122423
# 결과: 저체중
#
# 이름: 나가
# 몸무게: 58
# 키: 152
# BMI: 25.10387811634349
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 49
# 키: 174
# BMI: 16.1844365173735
# 결과: 저체중
#
# 이름: 타나
# 몸무게: 62
# 키: 155
# BMI: 25.806451612903224
# 결과: 과체중
#
# 이름: 바타
# 몸무게: 63
# 키: 186
# BMI: 18.210197710718
# 결과: 저체중
#
# 이름: 사타
# 몸무게: 43
# 키: 175
# BMI: 14.040816326530612
# 결과: 저체중
#
# 이름: 하아
# 몸무게: 75
# 키: 170
# BMI: 25.95155709342561
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 91
# 키: 188
# BMI: 25.746944318696244
# 결과: 과체중
#
# 이름: 자마
# 몸무게: 57
# 키: 158
# BMI: 22.832879346258608
# 결과: 정상 체중
#
# 이름: 하차
# 몸무게: 57
# 키: 188
# BMI: 16.127206880941603
# 결과: 저체중
#
# 이름: 나마
# 몸무게: 98
# 키: 199
# BMI: 24.74684982702457
# 결과: 정상 체중
#
# 이름: 나카
# 몸무게: 69
# 키: 152
# BMI: 29.864958448753463
# 결과: 과체중
#
# 이름: 마다
# 몸무게: 47
# 키: 169
# BMI: 16.45600644235146
# 결과: 저체중
#
# 이름: 카차
# 몸무게: 50
# 키: 193
# BMI: 13.423179145748879
# 결과: 저체중
#
# 이름: 다하
# 몸무게: 81
# 키: 144
# BMI: 39.0625
# 결과: 과체중
#
# 이름: 마타
# 몸무게: 41
# 키: 149
# BMI: 18.467636592946263
# 결과: 저체중
#
# 이름: 자카
# 몸무게: 94
# 키: 153
# BMI: 40.15549574949806
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 47
# 키: 161
# BMI: 18.132016511708652
# 결과: 저체중
#
# 이름: 타하
# 몸무게: 74
# 키: 149
# BMI: 33.331831899463985
# 결과: 과체중
#
# 이름: 타차
# 몸무게: 57
# 키: 142
# BMI: 28.268200753818686
# 결과: 과체중
#
# 이름: 마차
# 몸무게: 68
# 키: 173
# BMI: 22.720438370810918
# 결과: 정상 체중
#
# 이름: 라자
# 몸무게: 64
# 키: 148
# BMI: 29.218407596785976
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 93
# 키: 146
# BMI: 43.62919872396323
# 결과: 과체중
#
# 이름: 나아
# 몸무게: 42
# 키: 141
# BMI: 21.125697902519995
# 결과: 정상 체중
#
# 이름: 마나
# 몸무게: 83
# 키: 178
# BMI: 26.19618735008206
# 결과: 과체중
#
# 이름: 하마
# 몸무게: 90
# 키: 145
# BMI: 42.80618311533888
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 96
# 키: 172
# BMI: 32.44997295835587
# 결과: 과체중
#
# 이름: 바하
# 몸무게: 66
# 키: 198
# BMI: 16.835016835016834
# 결과: 저체중
#
# 이름: 바나
# 몸무게: 73
# 키: 188
# BMI: 20.654142145767317
# 결과: 정상 체중
#
# 이름: 타카
# 몸무게: 65
# 키: 160
# BMI: 25.390624999999996
# 결과: 과체중
#
# 이름: 나라
# 몸무게: 67
# 키: 191
# BMI: 18.36572462377676
# 결과: 저체중
#
# 이름: 카파
# 몸무게: 54
# 키: 193
# BMI: 14.49703347740879
# 결과: 저체중
#
# 이름: 바하
# 몸무게: 68
# 키: 180
# BMI: 20.98765432098765
# 결과: 정상 체중
#
# 이름: 하마
# 몸무게: 93
# 키: 187
# BMI: 26.59498412879979
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 99
# 키: 197
# BMI: 25.509546754618775
# 결과: 과체중
#
# 이름: 타아
# 몸무게: 40
# 키: 174
# BMI: 13.21178491214163
# 결과: 저체중
#
# 이름: 차카
# 몸무게: 91
# 키: 178
# BMI: 28.721121070571897
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 97
# 키: 172
# BMI: 32.787993510005414
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 99
# 키: 167
# BMI: 35.49786654236437
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 93
# 키: 141
# BMI: 46.77833106986571
# 결과: 과체중
#
# 이름: 마사
# 몸무게: 73
# 키: 153
# BMI: 31.184587124610193
# 결과: 과체중
#
# 이름: 차타
# 몸무게: 71
# 키: 156
# BMI: 29.17488494411571
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 51
# 키: 179
# BMI: 15.917106207671422
# 결과: 저체중
#
# 이름: 라마
# 몸무게: 52
# 키: 163
# BMI: 19.57168128269788
# 결과: 정상 체중
#
# 이름: 아아
# 몸무게: 93
# 키: 144
# BMI: 44.84953703703704
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 74
# 키: 175
# BMI: 24.163265306122447
# 결과: 정상 체중
#
# 이름: 자카
# 몸무게: 96
# 키: 146
# BMI: 45.036592231187846
# 결과: 과체중
#
# 이름: 자가
# 몸무게: 53
# 키: 152
# BMI: 22.939750692520775
# 결과: 정상 체중
#
# 이름: 가가
# 몸무게: 78
# 키: 171
# BMI: 26.674874320303687
# 결과: 과체중
#
# 이름: 차파
# 몸무게: 84
# 키: 171
# BMI: 28.726787729557817
# 결과: 과체중
#
# 이름: 바카
# 몸무게: 64
# 키: 144
# BMI: 30.8641975308642
# 결과: 과체중
#
# 이름: 아바
# 몸무게: 69
# 키: 150
# BMI: 30.666666666666668
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 94
# 키: 157
# BMI: 38.135421315266335
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 40
# 키: 170
# BMI: 13.84083044982699
# 결과: 저체중
#
# 이름: 카카
# 몸무게: 52
# 키: 197
# BMI: 13.398953850910871
# 결과: 저체중
#
# 이름: 차마
# 몸무게: 91
# 키: 150
# BMI: 40.44444444444444
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 62
# 키: 167
# BMI: 22.230987127541326
# 결과: 정상 체중
#
# 이름: 아파
# 몸무게: 79
# 키: 144
# BMI: 38.097993827160494
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 82
# 키: 168
# BMI: 29.053287981859416
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 87
# 키: 152
# BMI: 37.655817174515235
# 결과: 과체중
#
# 이름: 마다
# 몸무게: 99
# 키: 153
# BMI: 42.29142637447136
# 결과: 과체중
#
# 이름: 차파
# 몸무게: 55
# 키: 162
# BMI: 20.957171162932475
# 결과: 정상 체중
#
# 이름: 다카
# 몸무게: 78
# 키: 151
# BMI: 34.209025919915796
# 결과: 과체중
#
# 이름: 타가
# 몸무게: 97
# 키: 146
# BMI: 45.50572340026272
# 결과: 과체중
#
# 이름: 아사
# 몸무게: 86
# 키: 194
# BMI: 22.85046232330747
# 결과: 정상 체중
#
# 이름: 라다
# 몸무게: 89
# 키: 180
# BMI: 27.469135802469133
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 52
# 키: 155
# BMI: 21.64412070759625
# 결과: 정상 체중
#
# 이름: 자하
# 몸무게: 56
# 키: 143
# BMI: 27.385202210377038
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 82
# 키: 186
# BMI: 23.702162099664697
# 결과: 정상 체중
#
# 이름: 바나
# 몸무게: 51
# 키: 142
# BMI: 25.29260067446935
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 76
# 키: 170
# BMI: 26.29757785467128
# 결과: 과체중
#
# 이름: 하마
# 몸무게: 54
# 키: 148
# BMI: 24.653031409788166
# 결과: 정상 체중
#
# 이름: 가바
# 몸무게: 91
# 키: 175
# BMI: 29.714285714285715
# 결과: 과체중
#
# 이름: 바하
# 몸무게: 79
# 키: 148
# BMI: 36.06647187728269
# 결과: 과체중
#
# 이름: 바차
# 몸무게: 84
# 키: 172
# BMI: 28.393726338561386
# 결과: 과체중
#
# 이름: 가타
# 몸무게: 89
# 키: 166
# BMI: 32.29786616344898
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 72
# 키: 149
# BMI: 32.43097157785685
# 결과: 과체중
#
# 이름: 다사
# 몸무게: 76
# 키: 161
# BMI: 29.319856487018246
# 결과: 과체중
#
# 이름: 자나
# 몸무게: 83
# 키: 152
# BMI: 35.924515235457065
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 61
# 키: 161
# BMI: 23.533042706685695
# 결과: 정상 체중
#
# 이름: 자다
# 몸무게: 56
# 키: 195
# BMI: 14.72715318869165
# 결과: 저체중
#
# 이름: 라사
# 몸무게: 93
# 키: 170
# BMI: 32.17993079584775
# 결과: 과체중
#
# 이름: 타라
# 몸무게: 88
# 키: 194
# BMI: 23.381868423849507
# 결과: 정상 체중
#
# 이름: 타카
# 몸무게: 65
# 키: 164
# BMI: 24.167162403331353
# 결과: 정상 체중
#
# 이름: 차바
# 몸무게: 85
# 키: 180
# BMI: 26.234567901234566
# 결과: 과체중
#
# 이름: 하사
# 몸무게: 57
# 키: 192
# BMI: 15.462239583333334
# 결과: 저체중
#
# 이름: 타차
# 몸무게: 50
# 키: 182
# BMI: 15.094795314575533
# 결과: 저체중
#
# 이름: 사차
# 몸무게: 54
# 키: 165
# BMI: 19.834710743801654
# 결과: 정상 체중
#
# 이름: 타라
# 몸무게: 42
# 키: 178
# BMI: 13.255902032571644
# 결과: 저체중
#
# 이름: 바다
# 몸무게: 67
# 키: 172
# BMI: 22.647376960519203
# 결과: 정상 체중
#
# 이름: 다나
# 몸무게: 54
# 키: 176
# BMI: 17.43285123966942
# 결과: 저체중
#
# 이름: 차타
# 몸무게: 61
# 키: 187
# BMI: 17.444021847922443
# 결과: 저체중
#
# 이름: 마가
# 몸무게: 90
# 키: 184
# BMI: 26.583175803402646
# 결과: 과체중
#
# 이름: 가다
# 몸무게: 57
# 키: 166
# BMI: 20.685150239512268
# 결과: 정상 체중
#
# 이름: 하마
# 몸무게: 63
# 키: 184
# BMI: 18.608223062381853
# 결과: 정상 체중
#
# 이름: 나사
# 몸무게: 85
# 키: 191
# BMI: 23.299799895836188
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 87
# 키: 153
# BMI: 37.165192874535435
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 91
# 키: 161
# BMI: 35.10667026735079
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 73
# 키: 182
# BMI: 22.03840115928028
# 결과: 정상 체중
#
# 이름: 아파
# 몸무게: 77
# 키: 172
# BMI: 26.027582477014604
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 94
# 키: 172
# BMI: 31.77393185505679
# 결과: 과체중
#
# 이름: 가자
# 몸무게: 85
# 키: 198
# BMI: 21.68146107540047
# 결과: 정상 체중
#
# 이름: 아라
# 몸무게: 55
# 키: 161
# BMI: 21.218317194552675
# 결과: 정상 체중
#
# 이름: 아카
# 몸무게: 97
# 키: 194
# BMI: 25.77319587628866
# 결과: 과체중
#
# 이름: 다카
# 몸무게: 70
# 키: 148
# BMI: 31.95763330898466
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 63
# 키: 196
# BMI: 16.399416909620992
# 결과: 저체중
#
# 이름: 마라
# 몸무게: 56
# 키: 141
# BMI: 28.167597203359996
# 결과: 과체중
#
# 이름: 마마
# 몸무게: 46
# 키: 186
# BMI: 13.29633483639727
# 결과: 저체중
#
# 이름: 타아
# 몸무게: 68
# 키: 177
# BMI: 21.705129432793896
# 결과: 정상 체중
#
# 이름: 타하
# 몸무게: 50
# 키: 172
# BMI: 16.901027582477017
# 결과: 저체중
#
# 이름: 라차
# 몸무게: 42
# 키: 170
# BMI: 14.532871972318341
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 46
# 키: 159
# BMI: 18.19548277362446
# 결과: 저체중
#
# 이름: 가하
# 몸무게: 79
# 키: 147
# BMI: 36.55884122356426
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 49
# 키: 165
# BMI: 17.99816345270891
# 결과: 저체중
#
# 이름: 가가
# 몸무게: 84
# 키: 173
# BMI: 28.06642386982525
# 결과: 과체중
#
# 이름: 차사
# 몸무게: 77
# 키: 149
# BMI: 34.68312238187469
# 결과: 과체중
#
# 이름: 가사
# 몸무게: 91
# 키: 164
# BMI: 33.834027364663896
# 결과: 과체중
#
# 이름: 타사
# 몸무게: 99
# 키: 199
# BMI: 24.999368702810536
# 결과: 정상 체중
#
# 이름: 카카
# 몸무게: 47
# 키: 163
# BMI: 17.68978885166924
# 결과: 저체중
#
# 이름: 카파
# 몸무게: 70
# 키: 157
# BMI: 28.398718000730252
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 90
# 키: 168
# BMI: 31.88775510204082
# 결과: 과체중
#
# 이름: 마하
# 몸무게: 72
# 키: 196
# BMI: 18.74219075385256
# 결과: 정상 체중
#
# 이름: 카가
# 몸무게: 65
# 키: 147
# BMI: 30.080059234578187
# 결과: 과체중
#
# 이름: 하라
# 몸무게: 57
# 키: 140
# BMI: 29.081632653061227
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 70
# 키: 147
# BMI: 32.39390994493036
# 결과: 과체중
#
# 이름: 마아
# 몸무게: 63
# 키: 149
# BMI: 28.377100130624747
# 결과: 과체중
#
# 이름: 나나
# 몸무게: 43
# 키: 193
# BMI: 11.543934065344036
# 결과: 저체중
#
# 이름: 타마
# 몸무게: 77
# 키: 140
# BMI: 39.28571428571429
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 59
# 키: 154
# BMI: 24.87771968291449
# 결과: 정상 체중
#
# 이름: 가타
# 몸무게: 66
# 키: 167
# BMI: 23.66524436157625
# 결과: 정상 체중
#
# 이름: 나가
# 몸무게: 79
# 키: 176
# BMI: 25.50361570247934
# 결과: 과체중
#
# 이름: 자하
# 몸무게: 48
# 키: 155
# BMI: 19.979188345473464
# 결과: 정상 체중
#
# 이름: 파사
# 몸무게: 99
# 키: 154
# BMI: 41.74397031539889
# 결과: 과체중
#
# 이름: 타카
# 몸무게: 95
# 키: 151
# BMI: 41.6648392614359
# 결과: 과체중
#
# 이름: 카자
# 몸무게: 80
# 키: 156
# BMI: 32.87310979618672
# 결과: 과체중
#
# 이름: 자다
# 몸무게: 86
# 키: 146
# BMI: 40.34528054043911
# 결과: 과체중
#
# 이름: 카자
# 몸무게: 52
# 키: 199
# BMI: 13.130981540870179
# 결과: 저체중
#
# 이름: 바하
# 몸무게: 64
# 키: 162
# BMI: 24.38652644413961
# 결과: 정상 체중
#
# 이름: 아사
# 몸무게: 74
# 키: 192
# BMI: 20.07378472222222
# 결과: 정상 체중
#
# 이름: 바바
# 몸무게: 45
# 키: 152
# BMI: 19.47714681440443
# 결과: 정상 체중
#
# 이름: 자하
# 몸무게: 51
# 키: 189
# BMI: 14.277315864617453
# 결과: 저체중
#
# 이름: 나파
# 몸무게: 65
# 키: 181
# BMI: 19.840664204389366
# 결과: 정상 체중
#
# 이름: 아바
# 몸무게: 58
# 키: 167
# BMI: 20.796729893506402
# 결과: 정상 체중
#
# 이름: 아가
# 몸무게: 61
# 키: 176
# BMI: 19.692665289256198
# 결과: 정상 체중
#
# 이름: 다자
# 몸무게: 49
# 키: 161
# BMI: 18.90359168241966
# 결과: 정상 체중
#
# 이름: 자자
# 몸무게: 45
# 키: 177
# BMI: 14.363688595231254
# 결과: 저체중
#
# 이름: 나카
# 몸무게: 74
# 키: 175
# BMI: 24.163265306122447
# 결과: 정상 체중
#
# 이름: 나나
# 몸무게: 72
# 키: 175
# BMI: 23.510204081632654
# 결과: 정상 체중
#
# 이름: 차바
# 몸무게: 84
# 키: 167
# BMI: 30.11940191473341
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 53
# 키: 154
# BMI: 22.34778208804183
# 결과: 정상 체중
#
# 이름: 타차
# 몸무게: 53
# 키: 188
# BMI: 14.995473064735176
# 결과: 저체중
#
# 이름: 다다
# 몸무게: 47
# 키: 191
# BMI: 12.883418765932952
# 결과: 저체중
#
# 이름: 아마
# 몸무게: 66
# 키: 146
# BMI: 30.962657158941646
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 73
# 키: 172
# BMI: 24.675500270416443
# 결과: 정상 체중
#
# 이름: 마다
# 몸무게: 75
# 키: 190
# BMI: 20.775623268698062
# 결과: 정상 체중
#
# 이름: 가다
# 몸무게: 67
# 키: 167
# BMI: 24.023808670084982
# 결과: 정상 체중
#
# 이름: 파사
# 몸무게: 72
# 키: 153
# BMI: 30.757400999615534
# 결과: 과체중
#
# 이름: 차마
# 몸무게: 75
# 키: 154
# BMI: 31.624219935908247
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 69
# 키: 141
# BMI: 34.70650369699714
# 결과: 과체중
#
# 이름: 라차
# 몸무게: 94
# 키: 159
# BMI: 37.18207349392824
# 결과: 과체중
#
# 이름: 타마
# 몸무게: 44
# 키: 153
# BMI: 18.79618949976505
# 결과: 정상 체중
#
# 이름: 다다
# 몸무게: 96
# 키: 152
# BMI: 41.551246537396125
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 44
# 키: 149
# BMI: 19.818927075356967
# 결과: 정상 체중
#
# 이름: 가나
# 몸무게: 43
# 키: 197
# BMI: 11.079904145945529
# 결과: 저체중
#
# 이름: 아카
# 몸무게: 73
# 키: 161
# BMI: 28.162493730951734
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 46
# 키: 142
# BMI: 22.81293394167824
# 결과: 정상 체중
#
# 이름: 나나
# 몸무게: 66
# 키: 192
# BMI: 17.903645833333332
# 결과: 저체중
#
# 이름: 타차
# 몸무게: 69
# 키: 151
# BMI: 30.26183062146397
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 67
# 키: 182
# BMI: 20.227025721531216
# 결과: 정상 체중
#
# 이름: 자하
# 몸무게: 50
# 키: 186
# BMI: 14.452537865649207
# 결과: 저체중
#
# 이름: 타차
# 몸무게: 66
# 키: 184
# BMI: 19.494328922495274
# 결과: 정상 체중
#
# 이름: 파가
# 몸무게: 84
# 키: 163
# BMI: 31.615792841281195
# 결과: 과체중
#
# 이름: 마파
# 몸무게: 41
# 키: 156
# BMI: 16.847468770545692
# 결과: 저체중
#
# 이름: 가아
# 몸무게: 81
# 키: 157
# BMI: 32.86137368655929
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 89
# 키: 160
# BMI: 34.76562499999999
# 결과: 과체중
#
# 이름: 나자
# 몸무게: 52
# 키: 174
# BMI: 17.17532038578412
# 결과: 저체중
#
# 이름: 나가
# 몸무게: 89
# 키: 192
# BMI: 24.14279513888889
# 결과: 정상 체중
#
# 이름: 차하
# 몸무게: 83
# 키: 161
# BMI: 32.02036958450677
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 58
# 키: 198
# BMI: 14.794408733802674
# 결과: 저체중
#
# 이름: 라바
# 몸무게: 53
# 키: 179
# BMI: 16.541306451109516
# 결과: 저체중
#
# 이름: 마가
# 몸무게: 72
# 키: 186
# BMI: 20.811654526534856
# 결과: 정상 체중
#
# 이름: 가다
# 몸무게: 50
# 키: 195
# BMI: 13.149243918474689
# 결과: 저체중
#
# 이름: 나바
# 몸무게: 96
# 키: 198
# BMI: 24.487297214569942
# 결과: 정상 체중
#
# 이름: 타바
# 몸무게: 89
# 키: 149
# BMI: 40.0882843115175
# 결과: 과체중
#
# 이름: 바가
# 몸무게: 91
# 키: 155
# BMI: 37.87721123829344
# 결과: 과체중
#
# 이름: 사차
# 몸무게: 58
# 키: 166
# BMI: 21.04804761213529
# 결과: 정상 체중
#
# 이름: 마자
# 몸무게: 95
# 키: 197
# BMI: 24.478857996856398
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 93
# 키: 164
# BMI: 34.577632361689474
# 결과: 과체중
#
# 이름: 카자
# 몸무게: 66
# 키: 148
# BMI: 30.131482834185537
# 결과: 과체중
#
# 이름: 라하
# 몸무게: 45
# 키: 166
# BMI: 16.330381768036002
# 결과: 저체중
#
# 이름: 자하
# 몸무게: 70
# 키: 192
# BMI: 18.98871527777778
# 결과: 정상 체중
#
# 이름: 사카
# 몸무게: 88
# 키: 190
# BMI: 24.37673130193906
# 결과: 정상 체중
#
# 이름: 나사
# 몸무게: 76
# 키: 184
# BMI: 22.448015122873343
# 결과: 정상 체중
#
# 이름: 바마
# 몸무게: 65
# 키: 141
# BMI: 32.694532468185706
# 결과: 과체중
#
# 이름: 차라
# 몸무게: 80
# 키: 150
# BMI: 35.55555555555556
# 결과: 과체중
#
# 이름: 아파
# 몸무게: 63
# 키: 163
# BMI: 23.711844630960897
# 결과: 정상 체중
#
# 이름: 바하
# 몸무게: 53
# 키: 163
# BMI: 19.94805976890361
# 결과: 정상 체중
#
# 이름: 카타
# 몸무게: 55
# 키: 178
# BMI: 17.35891932836763
# 결과: 저체중
#
# 이름: 차타
# 몸무게: 55
# 키: 155
# BMI: 22.892819979188342
# 결과: 정상 체중
#
# 이름: 마가
# 몸무게: 63
# 키: 192
# BMI: 17.08984375
# 결과: 저체중
#
# 이름: 다가
# 몸무게: 49
# 키: 149
# BMI: 22.071077879374805
# 결과: 정상 체중
#
# 이름: 파타
# 몸무게: 42
# 키: 195
# BMI: 11.045364891518739
# 결과: 저체중
#
# 이름: 나타
# 몸무게: 71
# 키: 165
# BMI: 26.07897153351699
# 결과: 과체중
#
# 이름: 차차
# 몸무게: 73
# 키: 191
# BMI: 20.010416381129904
# 결과: 정상 체중
#
# 이름: 하다
# 몸무게: 61
# 키: 199
# BMI: 15.403651422943865
# 결과: 저체중
#
# 이름: 하카
# 몸무게: 91
# 키: 174
# BMI: 30.056810675122207
# 결과: 과체중
#
# 이름: 카타
# 몸무게: 86
# 키: 184
# BMI: 25.401701323251416
# 결과: 과체중
#
# 이름: 가사
# 몸무게: 71
# 키: 198
# BMI: 18.110396898275688
# 결과: 저체중
#
# 이름: 나사
# 몸무게: 86
# 키: 140
# BMI: 43.87755102040817
# 결과: 과체중
#
# 이름: 아파
# 몸무게: 63
# 키: 141
# BMI: 31.688546853779997
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 49
# 키: 194
# BMI: 13.01944946327984
# 결과: 저체중
#
# 이름: 차사
# 몸무게: 40
# 키: 143
# BMI: 19.560858721697887
# 결과: 정상 체중
#
# 이름: 차하
# 몸무게: 42
# 키: 163
# BMI: 15.807896420640597
# 결과: 저체중
#
# 이름: 타마
# 몸무게: 58
# 키: 184
# BMI: 17.131379962192817
# 결과: 저체중
#
# 이름: 사가
# 몸무게: 52
# 키: 158
# BMI: 20.82999519307803
# 결과: 정상 체중
#
# 이름: 카사
# 몸무게: 61
# 키: 176
# BMI: 19.692665289256198
# 결과: 정상 체중
#
# 이름: 아타
# 몸무게: 80
# 키: 160
# BMI: 31.249999999999993
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 62
# 키: 193
# BMI: 16.64474214072861
# 결과: 저체중
#
# 이름: 바아
# 몸무게: 43
# 키: 189
# BMI: 12.037736905461774
# 결과: 저체중
#
# 이름: 자차
# 몸무게: 79
# 키: 166
# BMI: 28.668892437218755
# 결과: 과체중
#
# 이름: 파마
# 몸무게: 48
# 키: 144
# BMI: 23.14814814814815
# 결과: 정상 체중
#
# 이름: 마바
# 몸무게: 52
# 키: 197
# BMI: 13.398953850910871
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 84
# 키: 199
# BMI: 21.21158556602106
# 결과: 정상 체중
#
# 이름: 하사
# 몸무게: 74
# 키: 192
# BMI: 20.07378472222222
# 결과: 정상 체중
#
# 이름: 라바
# 몸무게: 52
# 키: 140
# BMI: 26.530612244897963
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 62
# 키: 192
# BMI: 16.81857638888889
# 결과: 저체중
#
# 이름: 카차
# 몸무게: 92
# 키: 148
# BMI: 42.00146092037984
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 66
# 키: 173
# BMI: 22.052190183434128
# 결과: 정상 체중
#
# 이름: 나타
# 몸무게: 64
# 키: 144
# BMI: 30.8641975308642
# 결과: 과체중
#
# 이름: 파파
# 몸무게: 73
# 키: 150
# BMI: 32.44444444444444
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 42
# 키: 171
# BMI: 14.363393864778908
# 결과: 저체중
#
# 이름: 파하
# 몸무게: 56
# 키: 160
# BMI: 21.874999999999996
# 결과: 정상 체중
#
# 이름: 하하
# 몸무게: 72
# 키: 197
# BMI: 18.552397639722745
# 결과: 정상 체중
#
# 이름: 마가
# 몸무게: 43
# 키: 179
# BMI: 13.420305233919041
# 결과: 저체중
#
# 이름: 다나
# 몸무게: 57
# 키: 176
# BMI: 18.401342975206614
# 결과: 저체중
#
# 이름: 카나
# 몸무게: 65
# 키: 172
# BMI: 21.971335857220122
# 결과: 정상 체중
#
# 이름: 라아
# 몸무게: 68
# 키: 180
# BMI: 20.98765432098765
# 결과: 정상 체중
#
# 이름: 자차
# 몸무게: 87
# 키: 189
# BMI: 24.355421180818006
# 결과: 정상 체중
#
# 이름: 타아
# 몸무게: 91
# 키: 144
# BMI: 43.88503086419753
# 결과: 과체중
#
# 이름: 다바
# 몸무게: 42
# 키: 176
# BMI: 13.558884297520661
# 결과: 저체중
#
# 이름: 사마
# 몸무게: 85
# 키: 177
# BMI: 27.13141179099237
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 40
# 키: 194
# BMI: 10.628122010840684
# 결과: 저체중
#
# 이름: 자자
# 몸무게: 62
# 키: 144
# BMI: 29.899691358024693
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 95
# 키: 170
# BMI: 32.871972318339104
# 결과: 과체중
#
# 이름: 나나
# 몸무게: 70
# 키: 183
# BMI: 20.902385858042937
# 결과: 정상 체중
#
# 이름: 마가
# 몸무게: 96
# 키: 163
# BMI: 36.13233467574994
# 결과: 과체중
#
# 이름: 카바
# 몸무게: 78
# 키: 141
# BMI: 39.23343896182285
# 결과: 과체중
#
# 이름: 차가
# 몸무게: 85
# 키: 153
# BMI: 36.31082062454612
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 62
# 키: 159
# BMI: 24.524346347059055
# 결과: 정상 체중
#
# 이름: 파가
# 몸무게: 82
# 키: 182
# BMI: 24.755464315903875
# 결과: 정상 체중
#
# 이름: 나타
# 몸무게: 72
# 키: 185
# BMI: 21.0372534696859
# 결과: 정상 체중
#
# 이름: 차카
# 몸무게: 55
# 키: 159
# BMI: 21.75546853368142
# 결과: 정상 체중
#
# 이름: 파마
# 몸무게: 70
# 키: 149
# BMI: 31.530111256249718
# 결과: 과체중
#
# 이름: 라라
# 몸무게: 63
# 키: 171
# BMI: 21.545090797168363
# 결과: 정상 체중
#
# 이름: 라자
# 몸무게: 81
# 키: 141
# BMI: 40.74241738343142
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 83
# 키: 152
# BMI: 35.924515235457065
# 결과: 과체중
#
# 이름: 차자
# 몸무게: 72
# 키: 173
# BMI: 24.0569347455645
# 결과: 정상 체중
#
# 이름: 자아
# 몸무게: 51
# 키: 166
# BMI: 18.507766003774133
# 결과: 정상 체중
#
# 이름: 사사
# 몸무게: 47
# 키: 180
# BMI: 14.506172839506172
# 결과: 저체중
#
# 이름: 가사
# 몸무게: 66
# 키: 142
# BMI: 32.73160087284269
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 62
# 키: 159
# BMI: 24.524346347059055
# 결과: 정상 체중
#
# 이름: 카마
# 몸무게: 93
# 키: 144
# BMI: 44.84953703703704
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 45
# 키: 178
# BMI: 14.202752177755334
# 결과: 저체중
#
# 이름: 마라
# 몸무게: 49
# 키: 198
# BMI: 12.498724619936741
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 90
# 키: 191
# BMI: 24.67037636029714
# 결과: 정상 체중
#
# 이름: 바자
# 몸무게: 61
# 키: 159
# BMI: 24.128792373719392
# 결과: 정상 체중
#
# 이름: 파바
# 몸무게: 64
# 키: 185
# BMI: 18.699780861943022
# 결과: 정상 체중
#
# 이름: 카사
# 몸무게: 99
# 키: 188
# BMI: 28.010411951109102
# 결과: 과체중
#
# 이름: 바타
# 몸무게: 81
# 키: 189
# BMI: 22.67573696145125
# 결과: 정상 체중
#
# 이름: 다타
# 몸무게: 63
# 키: 190
# BMI: 17.451523545706372
# 결과: 저체중
#
# 이름: 카사
# 몸무게: 88
# 키: 151
# BMI: 38.59479847375115
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 64
# 키: 163
# BMI: 24.088223117166624
# 결과: 정상 체중
#
# 이름: 바사
# 몸무게: 64
# 키: 158
# BMI: 25.63691716071142
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 40
# 키: 183
# BMI: 11.944220490310249
# 결과: 저체중
#
# 이름: 차카
# 몸무게: 80
# 키: 183
# BMI: 23.888440980620498
# 결과: 정상 체중
#
# 이름: 타마
# 몸무게: 74
# 키: 157
# BMI: 30.021501886486266
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 41
# 키: 182
# BMI: 12.377732157951938
# 결과: 저체중
#
# 이름: 파사
# 몸무게: 76
# 키: 142
# BMI: 37.69093433842492
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 51
# 키: 147
# BMI: 23.601277245592115
# 결과: 정상 체중
#
# 이름: 나사
# 몸무게: 40
# 키: 192
# BMI: 10.850694444444445
# 결과: 저체중
#
# 이름: 나가
# 몸무게: 85
# 키: 194
# BMI: 22.584759273036454
# 결과: 정상 체중
#
# 이름: 사카
# 몸무게: 62
# 키: 182
# BMI: 18.717546190073662
# 결과: 정상 체중
#
# 이름: 바파
# 몸무게: 41
# 키: 151
# BMI: 17.981667470724968
# 결과: 저체중
#
# 이름: 바바
# 몸무게: 75
# 키: 185
# BMI: 21.913805697589478
# 결과: 정상 체중
#
# 이름: 타사
# 몸무게: 93
# 키: 166
# BMI: 33.74945565394107
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 76
# 키: 166
# BMI: 27.58020031934969
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 81
# 키: 144
# BMI: 39.0625
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 59
# 키: 189
# BMI: 16.516894823773132
# 결과: 저체중
#
# 이름: 나하
# 몸무게: 68
# 키: 194
# BMI: 18.067807418429165
# 결과: 저체중
#
# 이름: 사타
# 몸무게: 43
# 키: 174
# BMI: 14.202668780552253
# 결과: 저체중
#
# 이름: 마파
# 몸무게: 86
# 키: 147
# BMI: 39.798232218057294
# 결과: 과체중
#
# 이름: 카타
# 몸무게: 81
# 키: 174
# BMI: 26.7538644470868
# 결과: 과체중
#
# 이름: 파차
# 몸무게: 61
# 키: 165
# BMI: 22.4058769513315
# 결과: 정상 체중
#
# 이름: 자카
# 몸무게: 68
# 키: 167
# BMI: 24.38237297859371
# 결과: 정상 체중
#
# 이름: 타마
# 몸무게: 40
# 키: 156
# BMI: 16.43655489809336
# 결과: 저체중
#
# 이름: 카사
# 몸무게: 64
# 키: 163
# BMI: 24.088223117166624
# 결과: 정상 체중
#
# 이름: 타다
# 몸무게: 98
# 키: 189
# BMI: 27.434842249657066
# 결과: 과체중
#
# 이름: 파사
# 몸무게: 56
# 키: 143
# BMI: 27.385202210377038
# 결과: 과체중
#
# 이름: 자가
# 몸무게: 54
# 키: 173
# BMI: 18.042701059173375
# 결과: 저체중
#
# 이름: 다사
# 몸무게: 77
# 키: 175
# BMI: 25.142857142857142
# 결과: 과체중
#
# 이름: 아카
# 몸무게: 78
# 키: 193
# BMI: 20.940159467368254
# 결과: 정상 체중
#
# 이름: 나마
# 몸무게: 94
# 키: 182
# BMI: 28.378215191402003
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 80
# 키: 150
# BMI: 35.55555555555556
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 83
# 키: 160
# BMI: 32.42187499999999
# 결과: 과체중
#
# 이름: 파차
# 몸무게: 87
# 키: 157
# BMI: 35.295549515193315
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 79
# 키: 142
# BMI: 39.178734378099584
# 결과: 과체중
#
# 이름: 카가
# 몸무게: 58
# 키: 142
# BMI: 28.76413410037691
# 결과: 과체중
#
# 이름: 자하
# 몸무게: 51
# 키: 183
# BMI: 15.228881125145568
# 결과: 저체중
#
# 이름: 파카
# 몸무게: 85
# 키: 190
# BMI: 23.545706371191137
# 결과: 정상 체중
#
# 이름: 다나
# 몸무게: 86
# 키: 181
# BMI: 26.25072494734593
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 86
# 키: 168
# BMI: 30.470521541950117
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 54
# 키: 199
# BMI: 13.636019292442109
# 결과: 저체중
#
# 이름: 가카
# 몸무게: 57
# 키: 167
# BMI: 20.43816558499767
# 결과: 정상 체중
#
# 이름: 사파
# 몸무게: 51
# 키: 147
# BMI: 23.601277245592115
# 결과: 정상 체중
#
# 이름: 타아
# 몸무게: 81
# 키: 142
# BMI: 40.170601071216026
# 결과: 과체중
#
# 이름: 파자
# 몸무게: 51
# 키: 180
# BMI: 15.74074074074074
# 결과: 저체중
#
# 이름: 파타
# 몸무게: 48
# 키: 191
# BMI: 13.157534058825142
# 결과: 저체중
#
# 이름: 다마
# 몸무게: 58
# 키: 148
# BMI: 26.47918188458729
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 85
# 키: 196
# BMI: 22.12619741774261
# 결과: 정상 체중
#
# 이름: 다나
# 몸무게: 65
# 키: 191
# BMI: 17.81749403799238
# 결과: 저체중
#
# 이름: 사다
# 몸무게: 89
# 키: 155
# BMI: 37.04474505723204
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 59
# 키: 161
# BMI: 22.76146753597469
# 결과: 정상 체중
#
# 이름: 사사
# 몸무게: 86
# 키: 170
# BMI: 29.75778546712803
# 결과: 과체중
#
# 이름: 카가
# 몸무게: 98
# 키: 166
# BMI: 35.56394251705618
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 54
# 키: 176
# BMI: 17.43285123966942
# 결과: 저체중
#
# 이름: 다파
# 몸무게: 98
# 키: 154
# BMI: 41.32231404958678
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 88
# 키: 184
# BMI: 25.99243856332703
# 결과: 과체중
#
# 이름: 다자
# 몸무게: 89
# 키: 140
# BMI: 45.40816326530613
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 49
# 키: 171
# BMI: 16.75729284224206
# 결과: 저체중
#
# 이름: 차아
# 몸무게: 71
# 키: 180
# BMI: 21.91358024691358
# 결과: 정상 체중
#
# 이름: 하바
# 몸무게: 48
# 키: 185
# BMI: 14.024835646457266
# 결과: 저체중
#
# 이름: 자가
# 몸무게: 54
# 키: 159
# BMI: 21.359914560341757
# 결과: 정상 체중
#
# 이름: 차나
# 몸무게: 59
# 키: 149
# BMI: 26.575379487410476
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 44
# 키: 156
# BMI: 18.080210387902692
# 결과: 저체중
#
# 이름: 바바
# 몸무게: 77
# 키: 168
# BMI: 27.281746031746035
# 결과: 과체중
#
# 이름: 파다
# 몸무게: 89
# 키: 159
# BMI: 35.20430362722993
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 68
# 키: 148
# BMI: 31.0445580715851
# 결과: 과체중
#
# 이름: 타파
# 몸무게: 40
# 키: 146
# BMI: 18.765246762994934
# 결과: 정상 체중
#
# 이름: 가카
# 몸무게: 90
# 키: 190
# BMI: 24.930747922437675
# 결과: 정상 체중
#
# 이름: 나파
# 몸무게: 49
# 키: 168
# BMI: 17.361111111111114
# 결과: 저체중
#
# 이름: 나아
# 몸무게: 53
# 키: 146
# BMI: 24.86395196096829
# 결과: 정상 체중
#
# 이름: 타다
# 몸무게: 56
# 키: 191
# BMI: 15.350456401962665
# 결과: 저체중
#
# 이름: 파파
# 몸무게: 57
# 키: 176
# BMI: 18.401342975206614
# 결과: 저체중
#
# 이름: 다자
# 몸무게: 58
# 키: 164
# BMI: 21.564544913741823
# 결과: 정상 체중
#
# 이름: 아카
# 몸무게: 69
# 키: 162
# BMI: 26.291723822588015
# 결과: 과체중
#
# 이름: 타다
# 몸무게: 67
# 키: 182
# BMI: 20.227025721531216
# 결과: 정상 체중
#
# 이름: 가차
# 몸무게: 81
# 키: 193
# BMI: 21.745550216113184
# 결과: 정상 체중
#
# 이름: 카아
# 몸무게: 87
# 키: 196
# BMI: 22.646813827571847
# 결과: 정상 체중
#
# 이름: 아나
# 몸무게: 95
# 키: 180
# BMI: 29.320987654320987
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 44
# 키: 195
# BMI: 11.571334648257725
# 결과: 저체중
#
# 이름: 사다
# 몸무게: 83
# 키: 175
# BMI: 27.102040816326532
# 결과: 과체중
#
# 이름: 가타
# 몸무게: 63
# 키: 166
# BMI: 22.8625344752504
# 결과: 정상 체중
#
# 이름: 바마
# 몸무게: 72
# 키: 185
# BMI: 21.0372534696859
# 결과: 정상 체중
#
# 이름: 차마
# 몸무게: 91
# 키: 158
# BMI: 36.45249158788655
# 결과: 과체중
#
# 이름: 하사
# 몸무게: 89
# 키: 173
# BMI: 29.737044338267232
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 58
# 키: 170
# BMI: 20.06920415224914
# 결과: 정상 체중
#
# 이름: 아사
# 몸무게: 49
# 키: 195
# BMI: 12.886259040105195
# 결과: 저체중
#
# 이름: 차다
# 몸무게: 84
# 키: 143
# BMI: 41.07780331556556
# 결과: 과체중
#
# 이름: 다가
# 몸무게: 55
# 키: 156
# BMI: 22.600262984878366
# 결과: 정상 체중
#
# 이름: 라파
# 몸무게: 70
# 키: 182
# BMI: 21.132713440405748
# 결과: 정상 체중
#
# 이름: 나아
# 몸무게: 46
# 키: 159
# BMI: 18.19548277362446
# 결과: 저체중
#
# 이름: 가파
# 몸무게: 52
# 키: 156
# BMI: 21.367521367521366
# 결과: 정상 체중
#
# 이름: 다아
# 몸무게: 67
# 키: 181
# BMI: 20.45114617990904
# 결과: 정상 체중
#
# 이름: 하나
# 몸무게: 43
# 키: 187
# BMI: 12.296605564928935
# 결과: 저체중
#
# 이름: 자하
# 몸무게: 84
# 키: 144
# BMI: 40.50925925925926
# 결과: 과체중
#
# 이름: 사타
# 몸무게: 84
# 키: 185
# BMI: 24.543462381300216
# 결과: 정상 체중
#
# 이름: 다라
# 몸무게: 70
# 키: 160
# BMI: 27.343749999999996
# 결과: 과체중
#
# 이름: 사차
# 몸무게: 60
# 키: 150
# BMI: 26.666666666666668
# 결과: 과체중
#
# 이름: 바차
# 몸무게: 71
# 키: 163
# BMI: 26.722872520606725
# 결과: 과체중
#
# 이름: 타나
# 몸무게: 43
# 키: 142
# BMI: 21.32513390200357
# 결과: 정상 체중
#
# 이름: 타가
# 몸무게: 68
# 키: 180
# BMI: 20.98765432098765
# 결과: 정상 체중
#
# 이름: 나라
# 몸무게: 56
# 키: 198
# BMI: 14.284256708499132
# 결과: 저체중
#
# 이름: 나자
# 몸무게: 93
# 키: 158
# BMI: 37.25364524915878
# 결과: 과체중
#
# 이름: 타바
# 몸무게: 69
# 키: 184
# BMI: 20.380434782608695
# 결과: 정상 체중
#
# 이름: 차카
# 몸무게: 94
# 키: 158
# BMI: 37.6542220797949
# 결과: 과체중
#
# 이름: 카자
# 몸무게: 72
# 키: 181
# BMI: 21.97735111870822
# 결과: 정상 체중
#
# 이름: 다사
# 몸무게: 42
# 키: 196
# BMI: 10.932944606413995
# 결과: 저체중
#
# 이름: 바자
# 몸무게: 62
# 키: 156
# BMI: 25.476660092044707
# 결과: 과체중
#
# 이름: 파사
# 몸무게: 43
# 키: 179
# BMI: 13.420305233919041
# 결과: 저체중
#
# 이름: 마나
# 몸무게: 84
# 키: 165
# BMI: 30.85399449035813
# 결과: 과체중
#
# 이름: 다사
# 몸무게: 61
# 키: 176
# BMI: 19.692665289256198
# 결과: 정상 체중
#
# 이름: 사다
# 몸무게: 47
# 키: 193
# BMI: 12.617788397003947
# 결과: 저체중
#
# 이름: 파자
# 몸무게: 87
# 키: 192
# BMI: 23.600260416666668
# 결과: 정상 체중
#
# 이름: 자자
# 몸무게: 78
# 키: 181
# BMI: 23.808797045267237
# 결과: 정상 체중
#
# 이름: 아하
# 몸무게: 78
# 키: 159
# BMI: 30.853209920493647
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 48
# 키: 199
# BMI: 12.12090603772632
# 결과: 저체중
#
# 이름: 사하
# 몸무게: 47
# 키: 142
# BMI: 23.30886728823646
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 65
# 키: 141
# BMI: 32.694532468185706
# 결과: 과체중
#
# 이름: 라마
# 몸무게: 70
# 키: 170
# BMI: 24.221453287197235
# 결과: 정상 체중
#
# 이름: 라차
# 몸무게: 55
# 키: 158
# BMI: 22.031725684986377
# 결과: 정상 체중
#
# 이름: 자바
# 몸무게: 51
# 키: 176
# BMI: 16.464359504132233
# 결과: 저체중
#
# 이름: 라타
# 몸무게: 60
# 키: 192
# BMI: 16.276041666666668
# 결과: 저체중
#
# 이름: 라자
# 몸무게: 71
# 키: 166
# BMI: 25.76571345623458
# 결과: 과체중
#
# 이름: 나라
# 몸무게: 51
# 키: 177
# BMI: 16.278847074595422
# 결과: 저체중
#
# 이름: 가자
# 몸무게: 65
# 키: 191
# BMI: 17.81749403799238
# 결과: 저체중
#
# 이름: 아하
# 몸무게: 46
# 키: 172
# BMI: 15.548945375878855
# 결과: 저체중
#
# 이름: 아자
# 몸무게: 41
# 키: 182
# BMI: 12.377732157951938
# 결과: 저체중
#
# 이름: 파카
# 몸무게: 98
# 키: 177
# BMI: 31.28092182961473
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 82
# 키: 173
# BMI: 27.39817568244846
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 82
# 키: 147
# BMI: 37.94715164977556
# 결과: 과체중
#
# 이름: 파파
# 몸무게: 94
# 키: 199
# BMI: 23.73677432388071
# 결과: 정상 체중
#
# 이름: 파바
# 몸무게: 49
# 키: 153
# BMI: 20.932120124738347
# 결과: 정상 체중
#
# 이름: 하가
# 몸무게: 45
# 키: 164
# BMI: 16.731112433075552
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 51
# 키: 192
# BMI: 13.834635416666668
# 결과: 저체중
#
# 이름: 타바
# 몸무게: 90
# 키: 145
# BMI: 42.80618311533888
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 73
# 키: 180
# BMI: 22.530864197530864
# 결과: 정상 체중
#
# 이름: 차가
# 몸무게: 54
# 키: 158
# BMI: 21.63114885435026
# 결과: 정상 체중
#
# 이름: 마라
# 몸무게: 56
# 키: 175
# BMI: 18.285714285714285
# 결과: 저체중
#
# 이름: 바라
# 몸무게: 54
# 키: 151
# BMI: 23.683171790710933
# 결과: 정상 체중
#
# 이름: 나라
# 몸무게: 70
# 키: 191
# BMI: 19.188070502453332
# 결과: 정상 체중
#
# 이름: 마바
# 몸무게: 85
# 키: 153
# BMI: 36.31082062454612
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 59
# 키: 187
# BMI: 16.872086705367607
# 결과: 저체중
#
# 이름: 자마
# 몸무게: 98
# 키: 176
# BMI: 31.63739669421488
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 99
# 키: 190
# BMI: 27.423822714681442
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 54
# 키: 194
# BMI: 14.347964714634925
# 결과: 저체중
#
# 이름: 라자
# 몸무게: 95
# 키: 155
# BMI: 39.54214360041623
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 40
# 키: 184
# BMI: 11.814744801512287
# 결과: 저체중
#
# 이름: 다사
# 몸무게: 80
# 키: 164
# BMI: 29.744199881023206
# 결과: 과체중
#
# 이름: 자마
# 몸무게: 74
# 키: 197
# BMI: 19.067742018603933
# 결과: 정상 체중
#
# 이름: 카나
# 몸무게: 60
# 키: 199
# BMI: 15.1511325471579
# 결과: 저체중
#
# 이름: 하바
# 몸무게: 61
# 키: 140
# BMI: 31.12244897959184
# 결과: 과체중
#
# 이름: 사다
# 몸무게: 78
# 키: 161
# BMI: 30.091431657729252
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 85
# 키: 167
# BMI: 30.477966223242138
# 결과: 과체중
#
# 이름: 라마
# 몸무게: 49
# 키: 145
# BMI: 23.305588585017837
# 결과: 정상 체중
#
# 이름: 카아
# 몸무게: 72
# 키: 169
# BMI: 25.209201358495854
# 결과: 과체중
#
# 이름: 사카
# 몸무게: 71
# 키: 166
# BMI: 25.76571345623458
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 48
# 키: 151
# BMI: 21.051708258409718
# 결과: 정상 체중
#
# 이름: 아파
# 몸무게: 90
# 키: 180
# BMI: 27.777777777777775
# 결과: 과체중
#
# 이름: 파자
# 몸무게: 75
# 키: 176
# BMI: 24.212293388429753
# 결과: 정상 체중
#
# 이름: 바사
# 몸무게: 49
# 키: 167
# BMI: 17.569651116927822
# 결과: 저체중
#
# 이름: 아다
# 몸무게: 72
# 키: 170
# BMI: 24.913494809688583
# 결과: 정상 체중
#
# 이름: 나마
# 몸무게: 91
# 키: 168
# BMI: 32.242063492063494
# 결과: 과체중
#
# 이름: 하가
# 몸무게: 59
# 키: 156
# BMI: 24.243918474687703
# 결과: 정상 체중
#
# 이름: 아다
# 몸무게: 50
# 키: 143
# BMI: 24.451073402122358
# 결과: 정상 체중
#
# 이름: 아라
# 몸무게: 83
# 키: 155
# BMI: 34.54734651404786
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 99
# 키: 182
# BMI: 29.887694722859557
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 90
# 키: 176
# BMI: 29.054752066115704
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 77
# 키: 170
# BMI: 26.643598615916957
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 94
# 키: 190
# BMI: 26.038781163434905
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 47
# 키: 146
# BMI: 22.04916494651905
# 결과: 정상 체중
#
# 이름: 아다
# 몸무게: 72
# 키: 165
# BMI: 26.44628099173554
# 결과: 과체중
#
# 이름: 바타
# 몸무게: 59
# 키: 157
# BMI: 23.93606231490121
# 결과: 정상 체중
#
# 이름: 가하
# 몸무게: 93
# 키: 148
# BMI: 42.457998539079625
# 결과: 과체중
#
# 이름: 바차
# 몸무게: 42
# 키: 143
# BMI: 20.53890165778278
# 결과: 정상 체중
#
# 이름: 마사
# 몸무게: 84
# 키: 168
# BMI: 29.761904761904766
# 결과: 과체중
#
# 이름: 마아
# 몸무게: 69
# 키: 185
# BMI: 20.16070124178232
# 결과: 정상 체중
#
# 이름: 자하
# 몸무게: 91
# 키: 193
# BMI: 24.43018604526296
# 결과: 정상 체중
#
# 이름: 차사
# 몸무게: 90
# 키: 154
# BMI: 37.949063923089895
# 결과: 과체중
#
# 이름: 라나
# 몸무게: 86
# 키: 174
# BMI: 28.405337561104506
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 74
# 키: 180
# BMI: 22.839506172839506
# 결과: 정상 체중
#
# 이름: 하하
# 몸무게: 45
# 키: 180
# BMI: 13.888888888888888
# 결과: 저체중
#
# 이름: 다바
# 몸무게: 70
# 키: 142
# BMI: 34.71533425907558
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 46
# 키: 181
# BMI: 14.041085436952473
# 결과: 저체중
#
# 이름: 카다
# 몸무게: 57
# 키: 158
# BMI: 22.832879346258608
# 결과: 정상 체중
#
# 이름: 카나
# 몸무게: 54
# 키: 170
# BMI: 18.68512110726644
# 결과: 정상 체중
#
# 이름: 사차
# 몸무게: 66
# 키: 177
# BMI: 21.06674327300584
# 결과: 정상 체중
#
# 이름: 나자
# 몸무게: 83
# 키: 162
# BMI: 31.626276482243554
# 결과: 과체중
#
# 이름: 타다
# 몸무게: 93
# 키: 199
# BMI: 23.484255448094743
# 결과: 정상 체중
#
# 이름: 가자
# 몸무게: 98
# 키: 169
# BMI: 34.31252407128602
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 92
# 키: 170
# BMI: 31.83391003460208
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 55
# 키: 167
# BMI: 19.721036967980208
# 결과: 정상 체중
#
# 이름: 라하
# 몸무게: 89
# 키: 185
# BMI: 26.004382761139514
# 결과: 과체중
#
# 이름: 파사
# 몸무게: 71
# 키: 145
# BMI: 33.769322235434004
# 결과: 과체중
#
# 이름: 다가
# 몸무게: 79
# 키: 140
# BMI: 40.3061224489796
# 결과: 과체중
#
# 이름: 자나
# 몸무게: 43
# 키: 181
# BMI: 13.125362473672965
# 결과: 저체중
#
# 이름: 가하
# 몸무게: 94
# 키: 165
# BMI: 34.527089072543625
# 결과: 과체중
#
# 이름: 차가
# 몸무게: 80
# 키: 190
# BMI: 22.1606648199446
# 결과: 정상 체중
#
# 이름: 가라
# 몸무게: 98
# 키: 150
# BMI: 43.55555555555556
# 결과: 과체중
#
# 이름: 마아
# 몸무게: 49
# 키: 181
# BMI: 14.956808400231983
# 결과: 저체중
#
# 이름: 카카
# 몸무게: 98
# 키: 152
# BMI: 42.41689750692521
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 98
# 키: 160
# BMI: 38.28124999999999
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 40
# 키: 157
# BMI: 16.227838857560144
# 결과: 저체중
#
# 이름: 카마
# 몸무게: 47
# 키: 186
# BMI: 13.585385593710253
# 결과: 저체중
#
# 이름: 사나
# 몸무게: 84
# 키: 161
# BMI: 32.40615716986227
# 결과: 과체중
#
# 이름: 아하
# 몸무게: 48
# 키: 181
# BMI: 14.651567412472147
# 결과: 저체중
#
# 이름: 자타
# 몸무게: 71
# 키: 168
# BMI: 25.15589569160998
# 결과: 과체중
#
# 이름: 아다
# 몸무게: 95
# 키: 163
# BMI: 35.75595618954421
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 45
# 키: 152
# BMI: 19.47714681440443
# 결과: 정상 체중
#
# 이름: 가가
# 몸무게: 57
# 키: 197
# BMI: 14.687314798113839
# 결과: 저체중
#
# 이름: 바자
# 몸무게: 56
# 키: 195
# BMI: 14.72715318869165
# 결과: 저체중
#
# 이름: 다라
# 몸무게: 51
# 키: 151
# BMI: 22.367440024560327
# 결과: 정상 체중
#
# 이름: 다타
# 몸무게: 93
# 키: 161
# BMI: 35.878245438061796
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 96
# 키: 197
# BMI: 24.736530186296992
# 결과: 정상 체중
#
# 이름: 마사
# 몸무게: 91
# 키: 150
# BMI: 40.44444444444444
# 결과: 과체중
#
# 이름: 나타
# 몸무게: 95
# 키: 157
# BMI: 38.541117286705344
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 82
# 키: 199
# BMI: 20.70654781444913
# 결과: 정상 체중
#
# 이름: 아마
# 몸무게: 69
# 키: 184
# BMI: 20.380434782608695
# 결과: 정상 체중
#
# 이름: 나파
# 몸무게: 96
# 키: 165
# BMI: 35.26170798898072
# 결과: 과체중
#
# 이름: 라가
# 몸무게: 81
# 키: 190
# BMI: 22.437673130193907
# 결과: 정상 체중
#
# 이름: 다나
# 몸무게: 58
# 키: 172
# BMI: 19.60519199567334
# 결과: 정상 체중
#
# 이름: 파카
# 몸무게: 97
# 키: 182
# BMI: 29.283902910276534
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 98
# 키: 173
# BMI: 32.74416118146279
# 결과: 과체중
#
# 이름: 바자
# 몸무게: 97
# 키: 169
# BMI: 33.96239627464025
# 결과: 과체중
#
# 이름: 가하
# 몸무게: 66
# 키: 145
# BMI: 31.391200951248514
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 85
# 키: 161
# BMI: 32.79194475521777
# 결과: 과체중
#
# 이름: 사사
# 몸무게: 70
# 키: 191
# BMI: 19.188070502453332
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 74
# 키: 157
# BMI: 30.021501886486266
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 83
# 키: 190
# BMI: 22.991689750692522
# 결과: 정상 체중
#
# 이름: 카아
# 몸무게: 66
# 키: 150
# BMI: 29.333333333333332
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 77
# 키: 158
# BMI: 30.844415958980928
# 결과: 과체중
#
# 이름: 파나
# 몸무게: 53
# 키: 153
# BMI: 22.64086462471699
# 결과: 정상 체중
#
# 이름: 파나
# 몸무게: 40
# 키: 148
# BMI: 18.261504747991236
# 결과: 저체중
#
# 이름: 하아
# 몸무게: 90
# 키: 190
# BMI: 24.930747922437675
# 결과: 정상 체중
#
# 이름: 나바
# 몸무게: 43
# 키: 167
# BMI: 15.418265265875435
# 결과: 저체중
#
# 이름: 바나
# 몸무게: 42
# 키: 142
# BMI: 20.829200555445347
# 결과: 정상 체중
#
# 이름: 파라
# 몸무게: 92
# 키: 184
# BMI: 27.173913043478258
# 결과: 과체중
#
# 이름: 다자
# 몸무게: 82
# 키: 150
# BMI: 36.44444444444444
# 결과: 과체중
#
# 이름: 나자
# 몸무게: 98
# 키: 144
# BMI: 47.260802469135804
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 57
# 키: 164
# BMI: 21.192742415229034
# 결과: 정상 체중
#
# 이름: 나자
# 몸무게: 71
# 키: 168
# BMI: 25.15589569160998
# 결과: 과체중
#
# 이름: 바차
# 몸무게: 91
# 키: 191
# BMI: 24.94449165318933
# 결과: 정상 체중
#
# 이름: 나가
# 몸무게: 76
# 키: 193
# BMI: 20.403232301538296
# 결과: 정상 체중
#
# 이름: 타사
# 몸무게: 95
# 키: 177
# BMI: 30.323342589932647
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 64
# 키: 156
# BMI: 26.298487836949374
# 결과: 과체중
#
# 이름: 라라
# 몸무게: 78
# 키: 151
# BMI: 34.209025919915796
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 42
# 키: 160
# BMI: 16.406249999999996
# 결과: 저체중
#
# 이름: 자나
# 몸무게: 82
# 키: 198
# BMI: 20.91623303744516
# 결과: 정상 체중
#
# 이름: 사카
# 몸무게: 90
# 키: 196
# BMI: 23.427738442315704
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 44
# 키: 191
# BMI: 12.06107288725638
# 결과: 저체중
#
# 이름: 카바
# 몸무게: 86
# 키: 172
# BMI: 29.069767441860467
# 결과: 과체중
#
# 이름: 라차
# 몸무게: 61
# 키: 140
# BMI: 31.12244897959184
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 47
# 키: 166
# BMI: 17.056176513282043
# 결과: 저체중
#
# 이름: 파바
# 몸무게: 96
# 키: 161
# BMI: 37.03560819412831
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 46
# 키: 155
# BMI: 19.14672216441207
# 결과: 정상 체중
#
# 이름: 사아
# 몸무게: 99
# 키: 149
# BMI: 44.59258591955317
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 52
# 키: 178
# BMI: 16.41206918318394
# 결과: 저체중
#
# 이름: 사라
# 몸무게: 77
# 키: 152
# BMI: 33.3275623268698
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 45
# 키: 170
# BMI: 15.570934256055365
# 결과: 저체중
#
# 이름: 하하
# 몸무게: 69
# 키: 172
# BMI: 23.323418063818284
# 결과: 정상 체중
#
# 이름: 타나
# 몸무게: 52
# 키: 181
# BMI: 15.872531363511492
# 결과: 저체중
#
# 이름: 라가
# 몸무게: 62
# 키: 179
# BMI: 19.350207546580943
# 결과: 정상 체중
#
# 이름: 라하
# 몸무게: 82
# 키: 179
# BMI: 25.592209980961893
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 74
# 키: 195
# BMI: 19.46088099934254
# 결과: 정상 체중
#
# 이름: 다바
# 몸무게: 43
# 키: 146
# BMI: 20.172640270219556
# 결과: 정상 체중
#
# 이름: 가하
# 몸무게: 89
# 키: 151
# BMI: 39.03337572913469
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 97
# 키: 158
# BMI: 38.85595257170325
# 결과: 과체중
#
# 이름: 사사
# 몸무게: 60
# 키: 190
# BMI: 16.62049861495845
# 결과: 저체중
#
# 이름: 라바
# 몸무게: 48
# 키: 183
# BMI: 14.333064588372299
# 결과: 저체중
#
# 이름: 나타
# 몸무게: 60
# 키: 148
# BMI: 27.39225712198685
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 67
# 키: 172
# BMI: 22.647376960519203
# 결과: 정상 체중
#
# 이름: 하나
# 몸무게: 53
# 키: 185
# BMI: 15.485756026296565
# 결과: 저체중
#
# 이름: 자가
# 몸무게: 80
# 키: 140
# BMI: 40.81632653061225
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 61
# 키: 153
# BMI: 26.05835362467427
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 60
# 키: 195
# BMI: 15.779092702169626
# 결과: 저체중
#
# 이름: 아바
# 몸무게: 49
# 키: 171
# BMI: 16.75729284224206
# 결과: 저체중
#
# 이름: 파하
# 몸무게: 63
# 키: 146
# BMI: 29.555263651717024
# 결과: 과체중
#
# 이름: 파아
# 몸무게: 53
# 키: 193
# BMI: 14.228569894493813
# 결과: 저체중
#
# 이름: 타가
# 몸무게: 92
# 키: 187
# BMI: 26.309016557522373
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 93
# 키: 140
# BMI: 47.44897959183674
# 결과: 과체중
#
# 이름: 가타
# 몸무게: 41
# 키: 164
# BMI: 15.243902439024392
# 결과: 저체중
#
# 이름: 바카
# 몸무게: 83
# 키: 152
# BMI: 35.924515235457065
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 88
# 키: 182
# BMI: 26.56683975365294
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 95
# 키: 181
# BMI: 28.997893837184456
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 62
# 키: 191
# BMI: 16.995148159315807
# 결과: 저체중
#
# 이름: 나라
# 몸무게: 71
# 키: 170
# BMI: 24.56747404844291
# 결과: 정상 체중
#
# 이름: 마가
# 몸무게: 73
# 키: 147
# BMI: 33.782220371141655
# 결과: 과체중
#
# 이름: 마차
# 몸무게: 79
# 키: 164
# BMI: 29.372397382510414
# 결과: 과체중
#
# 이름: 사사
# 몸무게: 63
# 키: 157
# BMI: 25.558846200657225
# 결과: 과체중
#
# 이름: 가카
# 몸무게: 96
# 키: 161
# BMI: 37.03560819412831
# 결과: 과체중
#
# 이름: 하파
# 몸무게: 53
# 키: 168
# BMI: 18.77834467120182
# 결과: 정상 체중
#
# 이름: 마파
# 몸무게: 42
# 키: 168
# BMI: 14.880952380952383
# 결과: 저체중
#
# 이름: 파하
# 몸무게: 68
# 키: 153
# BMI: 29.04865649963689
# 결과: 과체중
#
# 이름: 카사
# 몸무게: 86
# 키: 145
# BMI: 40.903686087990486
# 결과: 과체중
#
# 이름: 아하
# 몸무게: 78
# 키: 189
# BMI: 21.83589485176787
# 결과: 정상 체중
#
# 이름: 차차
# 몸무게: 97
# 키: 199
# BMI: 24.494330951238602
# 결과: 정상 체중
#
# 이름: 사나
# 몸무게: 96
# 키: 198
# BMI: 24.487297214569942
# 결과: 정상 체중
#
# 이름: 아하
# 몸무게: 79
# 키: 180
# BMI: 24.382716049382715
# 결과: 정상 체중
#
# 이름: 아마
# 몸무게: 77
# 키: 162
# BMI: 29.340039628105465
# 결과: 과체중
#
# 이름: 하타
# 몸무게: 72
# 키: 171
# BMI: 24.622960911049557
# 결과: 정상 체중
#
# 이름: 하사
# 몸무게: 66
# 키: 185
# BMI: 19.284149013878743
# 결과: 정상 체중
#
# 이름: 하하
# 몸무게: 59
# 키: 142
# BMI: 29.260067446935132
# 결과: 과체중
#
# 이름: 자가
# 몸무게: 40
# 키: 149
# BMI: 18.017206432142697
# 결과: 저체중
#
# 이름: 타나
# 몸무게: 68
# 키: 197
# BMI: 17.52170888196037
# 결과: 저체중
#
# 이름: 하파
# 몸무게: 52
# 키: 171
# BMI: 17.783249546869126
# 결과: 저체중
#
# 이름: 라차
# 몸무게: 85
# 키: 189
# BMI: 23.79552644102909
# 결과: 정상 체중
#
# 이름: 차하
# 몸무게: 83
# 키: 150
# BMI: 36.888888888888886
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 57
# 키: 195
# BMI: 14.990138067061144
# 결과: 저체중
#
# 이름: 바파
# 몸무게: 50
# 키: 196
# BMI: 13.015410245730946
# 결과: 저체중
#
# 이름: 카파
# 몸무게: 52
# 키: 195
# BMI: 13.675213675213676
# 결과: 저체중
#
# 이름: 자라
# 몸무게: 89
# 키: 189
# BMI: 24.915315920606925
# 결과: 정상 체중
#
# 이름: 라아
# 몸무게: 41
# 키: 180
# BMI: 12.65432098765432
# 결과: 저체중
#
# 이름: 가파
# 몸무게: 66
# 키: 141
# BMI: 33.197525275388564
# 결과: 과체중
#
# 이름: 하하
# 몸무게: 59
# 키: 185
# BMI: 17.238860482103725
# 결과: 저체중
#
# 이름: 하파
# 몸무게: 45
# 키: 171
# BMI: 15.389350569405973
# 결과: 저체중
#
# 이름: 사가
# 몸무게: 87
# 키: 173
# BMI: 29.06879615089044
# 결과: 과체중
#
# 이름: 나자
# 몸무게: 45
# 키: 155
# BMI: 18.730489073881373
# 결과: 정상 체중
#
# 이름: 마하
# 몸무게: 92
# 키: 152
# BMI: 39.81994459833795
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 95
# 키: 192
# BMI: 25.770399305555557
# 결과: 과체중
#
# 이름: 타사
# 몸무게: 84
# 키: 145
# BMI: 39.95243757431629
# 결과: 과체중
#
# 이름: 가하
# 몸무게: 70
# 키: 198
# BMI: 17.855320885623918
# 결과: 저체중
#
# 이름: 마나
# 몸무게: 73
# 키: 156
# BMI: 29.996712689020377
# 결과: 과체중
#
# 이름: 파타
# 몸무게: 67
# 키: 154
# BMI: 28.25096980941137
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 95
# 키: 142
# BMI: 47.113667923031144
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 59
# 키: 173
# BMI: 19.713321527615356
# 결과: 정상 체중
#
# 이름: 라다
# 몸무게: 81
# 키: 141
# BMI: 40.74241738343142
# 결과: 과체중
#
# 이름: 나라
# 몸무게: 82
# 키: 181
# BMI: 25.029760996306585
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 72
# 키: 173
# BMI: 24.0569347455645
# 결과: 정상 체중
#
# 이름: 가차
# 몸무게: 94
# 키: 178
# BMI: 29.667971215755585
# 결과: 과체중
#
# 이름: 차나
# 몸무게: 70
# 키: 151
# BMI: 30.700407876847507
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 46
# 키: 165
# BMI: 16.896235078053262
# 결과: 저체중
#
# 이름: 차라
# 몸무게: 76
# 키: 168
# BMI: 26.92743764172336
# 결과: 과체중
#
# 이름: 마마
# 몸무게: 80
# 키: 199
# BMI: 20.201510062877198
# 결과: 정상 체중
#
# 이름: 아사
# 몸무게: 54
# 키: 165
# BMI: 19.834710743801654
# 결과: 정상 체중
#
# 이름: 마자
# 몸무게: 94
# 키: 178
# BMI: 29.667971215755585
# 결과: 과체중
#
# 이름: 다자
# 몸무게: 66
# 키: 151
# BMI: 28.946098855313362
# 결과: 과체중
#
# 이름: 라자
# 몸무게: 54
# 키: 172
# BMI: 18.25310978907518
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 55
# 키: 184
# BMI: 16.245274102079396
# 결과: 저체중
#
# 이름: 카하
# 몸무게: 83
# 키: 199
# BMI: 20.959066690235094
# 결과: 정상 체중
#
# 이름: 차아
# 몸무게: 87
# 키: 159
# BMI: 34.41319568055061
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 98
# 키: 154
# BMI: 41.32231404958678
# 결과: 과체중
#
# 이름: 라자
# 몸무게: 73
# 키: 179
# BMI: 22.783308885490467
# 결과: 정상 체중
#
# 이름: 라차
# 몸무게: 55
# 키: 162
# BMI: 20.957171162932475
# 결과: 정상 체중
#
# 이름: 바라
# 몸무게: 88
# 키: 170
# BMI: 30.449826989619382
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 70
# 키: 155
# BMI: 29.1363163371488
# 결과: 과체중
#
# 이름: 가파
# 몸무게: 63
# 키: 165
# BMI: 23.140495867768596
# 결과: 정상 체중
#
# 이름: 아라
# 몸무게: 50
# 키: 174
# BMI: 16.514731140177037
# 결과: 저체중
#
# 이름: 카아
# 몸무게: 94
# 키: 144
# BMI: 45.33179012345679
# 결과: 과체중
#
# 이름: 가가
# 몸무게: 98
# 키: 165
# BMI: 35.99632690541782
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 50
# 키: 197
# BMI: 12.883609472029685
# 결과: 저체중
#
# 이름: 하다
# 몸무게: 92
# 키: 185
# BMI: 26.880934989043094
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 69
# 키: 177
# BMI: 22.024322512687924
# 결과: 정상 체중
#
# 이름: 바자
# 몸무게: 43
# 키: 192
# BMI: 11.664496527777779
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 63
# 키: 144
# BMI: 30.381944444444446
# 결과: 과체중
#
# 이름: 자하
# 몸무게: 52
# 키: 147
# BMI: 24.06404738766255
# 결과: 정상 체중
#
# 이름: 마파
# 몸무게: 70
# 키: 164
# BMI: 26.026174895895306
# 결과: 과체중
#
# 이름: 나가
# 몸무게: 52
# 키: 148
# BMI: 23.739956172388606
# 결과: 정상 체중
#
# 이름: 타바
# 몸무게: 48
# 키: 189
# BMI: 13.437473754934073
# 결과: 저체중
#
# 이름: 나아
# 몸무게: 66
# 키: 180
# BMI: 20.37037037037037
# 결과: 정상 체중
#
# 이름: 자다
# 몸무게: 40
# 키: 198
# BMI: 10.20304050607081
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 86
# 키: 147
# BMI: 39.798232218057294
# 결과: 과체중
#
# 이름: 파파
# 몸무게: 78
# 키: 187
# BMI: 22.305470559638533
# 결과: 정상 체중
#
# 이름: 하마
# 몸무게: 68
# 키: 160
# BMI: 26.562499999999996
# 결과: 과체중
#
# 이름: 파타
# 몸무게: 84
# 키: 160
# BMI: 32.81249999999999
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 88
# 키: 152
# BMI: 38.08864265927978
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 80
# 키: 180
# BMI: 24.691358024691358
# 결과: 정상 체중
#
# 이름: 가나
# 몸무게: 69
# 키: 171
# BMI: 23.59700420642249
# 결과: 정상 체중
#
# 이름: 카타
# 몸무게: 72
# 키: 153
# BMI: 30.757400999615534
# 결과: 과체중
#
# 이름: 가아
# 몸무게: 71
# 키: 180
# BMI: 21.91358024691358
# 결과: 정상 체중
#
# 이름: 차마
# 몸무게: 87
# 키: 181
# BMI: 26.555965935105768
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 67
# 키: 178
# BMI: 21.146319909102385
# 결과: 정상 체중
#
# 이름: 다라
# 몸무게: 48
# 키: 198
# BMI: 12.243648607284971
# 결과: 저체중
#
# 이름: 사나
# 몸무게: 80
# 키: 173
# BMI: 26.729927495071667
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 91
# 키: 180
# BMI: 28.086419753086417
# 결과: 과체중
#
# 이름: 마마
# 몸무게: 44
# 키: 184
# BMI: 12.996219281663516
# 결과: 저체중
#
# 이름: 하파
# 몸무게: 88
# 키: 142
# BMI: 43.642134497123585
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 66
# 키: 197
# BMI: 17.006364503079183
# 결과: 저체중
#
# 이름: 나자
# 몸무게: 42
# 키: 161
# BMI: 16.203078584931134
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 80
# 키: 152
# BMI: 34.62603878116344
# 결과: 과체중
#
# 이름: 자가
# 몸무게: 57
# 키: 175
# BMI: 18.612244897959183
# 결과: 정상 체중
#
# 이름: 나차
# 몸무게: 89
# 키: 174
# BMI: 29.396221429515126
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 74
# 키: 166
# BMI: 26.854405574103644
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 56
# 키: 143
# BMI: 27.385202210377038
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 49
# 키: 177
# BMI: 15.640460914807365
# 결과: 저체중
#
# 이름: 바타
# 몸무게: 68
# 키: 153
# BMI: 29.04865649963689
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 63
# 키: 188
# BMI: 17.824807605251245
# 결과: 저체중
#
# 이름: 라마
# 몸무게: 47
# 키: 149
# BMI: 21.170217557767668
# 결과: 정상 체중

# %% [markdown]
# ### 제너레이터 함수

# %%
# 함수를 선언합니다. 
def test(): 
    print("함수가 호출되었습니다.") 
    yield "test" 

# 함수를 호출합니다. 
print("A 지점 통과") 
test() 

print("B 지점 통과") 
test() 
print(test())
# Out:
# A 지점 통과
# B 지점 통과
# <generator object test at 0x7aee881a8a50>

# %% [markdown]
# ### 제너레이터 객체와 next() 함수

# %%
# 함수를 선언합니다.
def test(): 
    print("A 지점 통과")
    yield 1 
    print("B 지점 통과") 
    yield 2 
    print("C 지점 통과") 

# 함수를 호출합니다. 
output = test() 

# next() 함수를 호출합니다.
print("D 지점 통과") 
a = next(output) 
print(a) 
print("E 지점 통과") 
b = next(output) 
print(b) 
print("F 지점 통과") 
c = next(output) 
print(c) 

# 한 번 더 실행하기
next(output)
# Out:
# D 지점 통과
# A 지점 통과
# 1
# E 지점 통과
# B 지점 통과
# 2
# F 지점 통과
# C 지점 통과
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[20], line 20
#      18 print(b)
#      19 print("F 지점 통과")
# ---> 20 c = next(output)
#      21 print(c)
#      23 # 한 번 더 실행하기
#
# StopIteration:

# %% [markdown]
# ### 키워드 매개변수에 함수 전달하기

# %%
books = [{ 
    "제목": "혼자 공부하는 파이썬",
    "가격": 18000 
}, {
    "제목": "혼자 공부하는 머신러닝 + 딥러닝",
    "가격": 26000
},{
    "제목": "혼자 공부하는 자바스크립트",
    "가격": 24000 
}]

def 가격추출함수(book): return book["가격"]
print("# 가장 저렴한 책") 
print(min(books, key=가격추출함수))
print() 

print("# 가장 비싼 책") 
print(max(books, key=가격추출함수))
# Out:
# # 가장 저렴한 책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %% [markdown]
# ### 콜백 함수를 람다로 바꾸기

# %%
books = [{ 
    "제목": "혼자 공부하는 파이썬",
    "가격": 18000 
}, {
    "제목": "혼자 공부하는 머신러닝 + 딥러닝",
    "가격": 26000
},{
    "제목": "혼자 공부하는 자바스크립트",
    "가격": 24000 
}]

print("# 가장 저렴한 책")
print(min(books, key=lambda book: book["가격"])) 
print() 

print("# 가장 비싼 책") 
print(max(books, key=lambda book: book["가격"]))
# Out:
# # 가장 저렴한 책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %% [markdown]
# ### 딕셔너리 오름차순 정렬하기

# %%
books = [{ 
    "제목": "혼자 공부하는 파이썬",
    "가격": 18000 
}, {
    "제목": "혼자 공부하는 머신러닝 + 딥러닝",
    "가격": 26000
},{
    "제목": "혼자 공부하는 자바스크립트",
    "가격": 24000 
}]

print("# 가격 오름차순 정렬")
books.sort(key=lambda book: book["가격"])
for book in books:
    print(book)
# Out:
# # 가격 오름차순 정렬
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
# {'제목': '혼자 공부하는 자바스크립트', '가격': 24000}
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %% [markdown]
# - 튜플
#     - 리스트와 비슷
#     - but, 요소를 수정할수 없는 파이썬의 특별한 문법
#     - 괄호를 생략해서 다양하게 활용 가능
# - 람다
#     - 함수를 짧게 쓸 수 있는 파이썬의 특별한 문법
# - with 구문
#     - 블록을 벗어날 때 close() 함수를 자동으로 호출해주는 구문

# %% [markdown]
# ### 확인 문제
# 1. 다음은 많은 사람들이 파이썬으로 프로그램을 개발하다가 막히는 대표적인 코드입니다. 빈 칸을 채워서 실행 결과처럼 출력되게 만들어 주세요.

# %%
numbers = [1, 2, 3, 4, 5, 6]

print("::".join(map(str, numbers)))
# Out:
# 1::2::3::4::5::6

# %% [markdown]
# 2. 다음 코드의 빈칸을 채워서 실행 결과처럼 결과가 나오게 해주세요.

# %%
numbers = list(range(1, 10 + 1)) 
print("# 홀수만 추출하기")
print(list(filter(lambda x: x % 2 == 1, numbers))) 
print() 

print("# 3 이상, 7 미만 추출하기")
print(list(filter(lambda x: 3 <= x < 7, numbers))) 
print() 

print("# 제곱해서 50 미만 추출하기")
print(list(filter(lambda x: x ** 2 < 50, numbers)))
# Out:
# # 홀수만 추출하기
# [1, 3, 5, 7, 9]
#
# # 3 이상, 7 미만 추출하기
# [3, 4, 5, 6]
#
# # 제곱해서 50 미만 추출하기
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ### 도전 문제
# 재귀 함수를 연습할 수 있는 유명한 문제인 하노이 탑 문제에 도전해 보세요. 하노이 탑은 다음과 같은 3개의 기둥과 크기가 다른 원판들이 원뿔 형태로 존재합니다. 이때 다음 규칙을 지켜 원 판을 다른 기둥으로 옮겨야 합니다.
#     > 1. 한 번에 한 개의 원판만 옮길 수 있다.
#     > 2. 큰 원판이 작은 원판 위에 있어서는 안 된다.
#     기본적으로 원판의 개수가n개일 때 2n-1 회 움직여야 원판을 모두 옮길 수 있다고 알려져 있습니다.
#
# 1. 하노이 탑
#     원판 개수가 4개일 때 어떻게 원판을 옮겨야 하는지 출력하도록 프로그램을 구현해 보세요.
#     하노이 탑에는 3개의 기둥이 있습니다. 각각의 기둥을 A, B, C라고 표현하겠습니다. 그리고 ‘처 음 원판이 있는 기둥’을 ‘시작 기둥’, ‘원판을 옮겨야 하는 기둥’을 ‘대상 기둥’, ‘보조적으로 활용하 는 기둥’을 ‘보조 기둥’이라고 하겠습니다.
#
#     일단 원판이 하나일 때입니다. 원판이 하나일 때는 ”시작 기둥’에서 "대상 기둥"으로 원판을 옮기 기만 하면 됩니다.
#
#     코드로 옮긴다면, 다음과 같을 것입니다.
#
#         > if 원판이 1개:
#             > 이동 from 시작기둥 to 대상기둥
#
#     시작 기둥이 "A"이고, 대상 기둥이 "B"라면 위 코드를 다음과 같이 출력할 것입니다.
#
#         > A탑 → B탑
#
#     이어서 원판이 2개일 때입니다. 다음과 같은 과정에 따라서 1위에 있는 원판을 "보조 기둥’’으로 옮기고 2 아래에 있는 원판을 "대상 기둥"으로 옮긴 뒤 3 "보조 기둥"에 있던 원판을 "대상 기둥" 으로 옮기 면 4 모든 원판이 "대상 기둥"으로 옮겨 집니다.
#
#     이를 확장해 보겠습니다. 다음 그림과 같이 원판 하나와 원판 덩어리가 있다면, 아래에 있는 원판 을 "시작 기둥"에서 "대상 기둥’으로옮기려면 어떻게 해야할까요?
#
#     1 일단 덩어리를 "보조 기둥"으로 옮깁니다. 2 이어서 아래의 원판을 "대상 기둥"으로 옮깁니다. 3 "보조 기둥"에 있던 덩어리를 "대상 기둥"으로 옮깁니다. 4 모든 원판이 "대상 기둥"으로 옮겨 집니다.
#
#     그림을 코드로 옮긴면 다음과 같습니다.
#         > if 원판이 2개 이상
#             > 덩어리 이동 from 시작기둥 to 보조기둥
#             > 이동 from 시작기둥 to 대상기둥
#             > 덩어리 이동 from 보조기둥 to 대상기둥
#
#     그리고 이전과 마찬가지로 시작 기둥에서 대상 기둥으로 이동을 줄력하면 됩니다.
#
#         > 이동 from 시작기둥 to 대상기둥
#
#         > A탑 → B탑
#
#     그렇다면 "원판이 2개 이상인 덩어리 이동"은 어떻게 표현해야 할까요? 원판의 덩어리도 하나의 하노이 탑 문제입니다. 따라서 함수를 재귀 호출하면 될 것입니다.
#
#     알고리즘을 전체적으로 풀어서 적어보면 다음과 같습니다. 답은 거의 다 나왔습니다. 남은 부분 은 직접 구현해 보세요!

# %%
def hanoi_top(move_cir, start_peg, peg, support_peg): 
    if move_cir == 1:
        print(start_peg, "→", peg)
    else:
        hanoi_top(move_cir - 1, start_peg, peg, support_peg)
        print(start_peg, "→", support_peg)
        hanoi_top(move_cir - 1, support_peg, peg, start_peg)

n = int(input("원판의 개수: "))
hanoi_top(n, "A탑", "B탑", "C탑")
# Out:
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑
# C탑 → A탑
# A탑 → B탑
# C탑 → A탑
# A탑 → B탑
# A탑 → C탑
# C탑 → B탑

# %% [markdown]
# 2. 하노이 탑이동 횟수
#     1번에서 하노이 탑을 풀어 보았습니다. 이번에는 다음과 같이 하노이 탑의 이동 횟수를 다음과 같이 출력해 보세요. 앞에서 설명한 모든 내용을 응용해 보면 됩니다.
#
#         > 원판의 개수를 입력해주세요: 20
#         > 이동 횟수는 1048575회입니다.
#
#     하노이 탑 알고리즘은 쉬운 발상은 아닙니다. 처음 이런 문제를 풀어본다면 며칠이 걸릴 수 있으 니 문제를 풀지 못한다고 하여 너무 실망하지 마세요!

# %%
count = 0
def hanoi_top(move_cir, start_peg, peg, support_peg):
    global count
    if move_cir == 1:
        count += 1
    else:
        hanoi_top(move_cir - 1, start_peg, support_peg, peg)
        count += 1
        hanoi_top(move_cir - 1, support_peg, peg, start_peg)

n = int(input("원판의 개수: "))
hanoi_top(n, "A탑", "B탑", "C탑")
print(f"이동 횟수는 {count}회 입니다.")

def hanoi_top_count(n):
    return (2 ** n) - 1 

n = int(input("원판의 개수를 입력해주세요: "))
print(f"이동 횟수는 {hanoi_top_count(n)}회 입니다.")
# Out:
# 이동 횟수는 1023회 입니다.
# 이동 횟수는 1023회 입니다.
